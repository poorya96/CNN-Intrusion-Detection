# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the PDAE Model

# %%
import torch
import torch.nn as nn

class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dropout_rate=0.5):
        super(DeepAutoencoder, self).__init__()
        self.num_input_features = num_input_features

        # Standard Encoder
        self.encoder_standard = nn.Sequential(
            nn.Linear(num_input_features, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 32)
        )

        # Adjust input size for Conv1d with dilation=3
        conv1d_output_size = (num_input_features - 3 * (3 - 1) - 1) + 1  # Adjusted for dilation=3

        # Dilated Encoder with dilation factor of 3
        self.encoder_dilated = nn.Sequential(
            nn.Linear(num_input_features, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Conv1d(in_channels=1, out_channels=1, kernel_size=3, stride=1, dilation=3),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(58, 32)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(32 + 32, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, num_input_features)
        )

        # Dilated Decoder with adjusted input and output sizes for dilation=3
        self.decoder_dilated = nn.Sequential(
            nn.Linear(32, conv1d_output_size),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.ConvTranspose1d(1, 1, kernel_size=3, stride=1, dilation=3),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(conv1d_output_size, num_input_features)
        )

        # Classifier
        self.classifier = nn.Linear(64, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        encoded_standard = self.encoder_standard(x)
        encoded_dilated = self.encoder_dilated(x.unsqueeze(1))
        encoded_combined = torch.cat((encoded_standard, encoded_dilated), dim=1)
        decoded = self.decoder(encoded_combined)
        classification = self.classifier(encoded_combined)
        return decoded, classification


# Example usage
num_classes = len(label_encoder.classes_)
print(num_classes)  # Update this based on your dataset
num_input_features = 49  # Update this based on your dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes).to(device)
# Out:
# 5

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.04811575316051911, Classification Loss: 0.2136134694531172
# Epoch 1, Validation Accuracy: 0.9558
# Epoch [2/100], Reconstruction Loss: 0.04819276238106454, Classification Loss: 0.185513364967229
# Epoch 2, Validation Accuracy: 0.9387
# Epoch [3/100], Reconstruction Loss: 0.048020680659337005, Classification Loss: 0.1778702250058905
# Epoch 3, Validation Accuracy: 0.9602
# Epoch [4/100], Reconstruction Loss: 0.04795601949050236, Classification Loss: 0.15840743240245203
# Epoch 4, Validation Accuracy: 0.9700
# Epoch [5/100], Reconstruction Loss: 0.048028437006172875, Classification Loss: 0.1542021955147782
# Epoch 5, Validation Accuracy: 0.9656
# Epoch [6/100], Reconstruction Loss: 0.04798340949490244, Classification Loss: 0.15190068942859286
# Epoch 6, Validation Accuracy: 0.9718
# Epoch [7/100], Reconstruction Loss: 0.047992520691207685, Classification Loss: 0.14937693970652927
# Epoch 7, Validation Accuracy: 0.9698
# Epoch [8/100], Reconstruction Loss: 0.047985451790673525, Classification Loss: 0.14107881639646114
# Epoch 8, Validation Accuracy: 0.9672
# Epoch [9/100], Reconstruction Loss: 0.0479547836813604, Classification Loss: 0.14152604076258057
# Epoch 9, Validation Accuracy: 0.9691
# Epoch [10/100], Reconstruction Loss: 0.04796847629047164, Classification Loss: 0.1360297444644627
# Epoch 10, Validation Accuracy: 0.9747
# Epoch [11/100], Reconstruction Loss: 0.04797341508690935, Classification Loss: 0.1317239853149075
# Epoch 11, Validation Accuracy: 0.9712
# Epoch [12/100], Reconstruction Loss: 0.047978750931383096, Classification Loss: 0.1324913008548758
# Epoch 12, Validation Accuracy: 0.9646
# Epoch [13/100], Reconstruction Loss: 0.04799344329923491, Classification Loss: 0.12875207458116544
# Epoch 13, Validation Accuracy: 0.9710
# Epoch [14/100], Reconstruction Loss: 0.04797534190572128, Classification Loss: 0.1299118926132084
# Epoch 14, Validation Accuracy: 0.9674
# Epoch [15/100], Reconstruction Loss: 0.04799553563271104, Classification Loss: 0.12313227123238481
# Epoch 15, Validation Accuracy: 0.9732
# Epoch [16/100], Reconstruction Loss: 0.048001547969649186, Classification Loss: 0.12297493078776905
# Epoch 16, Validation Accuracy: 0.9755
# Epoch [17/100], Reconstruction Loss: 0.04798223240876946, Classification Loss: 0.1199395250483561
# Epoch 17, Validation Accuracy: 0.9707
# Epoch [18/100], Reconstruction Loss: 0.047996043953689865, Classification Loss: 0.12457733751096071
# Epoch 18, Validation Accuracy: 0.9668
# Epoch [19/100], Reconstruction Loss: 0.04798599259191638, Classification Loss: 0.11925725043789343
# Epoch 19, Validation Accuracy: 0.9645
# Epoch [20/100], Reconstruction Loss: 0.04800200907491567, Classification Loss: 0.12031902765064807
# Epoch 20, Validation Accuracy: 0.9656
# Epoch [21/100], Reconstruction Loss: 0.04802662121877453, Classification Loss: 0.11590428143235522
# Epoch 21, Validation Accuracy: 0.9782
# Epoch [22/100], Reconstruction Loss: 0.048014107631820804, Classification Loss: 0.11938172178447186
# Epoch 22, Validation Accuracy: 0.9817
# Epoch [23/100], Reconstruction Loss: 0.04803351829834916, Classification Loss: 0.11626972623309141
# Epoch 23, Validation Accuracy: 0.9719
# Epoch [24/100], Reconstruction Loss: 0.04804437955902888, Classification Loss: 0.11736477156490442
# Epoch 24, Validation Accuracy: 0.9697
# Epoch [25/100], Reconstruction Loss: 0.04802706285765272, Classification Loss: 0.11738695389358157
# Epoch 25, Validation Accuracy: 0.9722
# Epoch [26/100], Reconstruction Loss: 0.048015691977368484, Classification Loss: 0.11860548978613757
# Epoch 26, Validation Accuracy: 0.9688
# Epoch [27/100], Reconstruction Loss: 0.04802028698621144, Classification Loss: 0.11337639418567232
# Epoch 27, Validation Accuracy: 0.9698
# Epoch [28/100], Reconstruction Loss: 0.048028591531257776, Classification Loss: 0.1136111028987694
# Epoch 28, Validation Accuracy: 0.9720
# Epoch [29/100], Reconstruction Loss: 0.04802484337962337, Classification Loss: 0.1123171632104613
# Epoch 29, Validation Accuracy: 0.9722
# Epoch [30/100], Reconstruction Loss: 0.048040031978454606, Classification Loss: 0.11007483939212809
# Epoch 30, Validation Accuracy: 0.9732
# Epoch [31/100], Reconstruction Loss: 0.04802262188379614, Classification Loss: 0.10979566170894522
# Epoch 31, Validation Accuracy: 0.9718
# Epoch [32/100], Reconstruction Loss: 0.04799426157151497, Classification Loss: 0.10985935533888772
# Epoch 32, Validation Accuracy: 0.9795
# Epoch [33/100], Reconstruction Loss: 0.04798402407573898, Classification Loss: 0.11056506569260496
# Epoch 33, Validation Accuracy: 0.9763
# Epoch [34/100], Reconstruction Loss: 0.04796919757631615, Classification Loss: 0.10817590960914623
# Epoch 34, Validation Accuracy: 0.9706
# Epoch [35/100], Reconstruction Loss: 0.04797953421712736, Classification Loss: 0.10547671828323929
# Epoch 35, Validation Accuracy: 0.9750
# Epoch [36/100], Reconstruction Loss: 0.04796220023991376, Classification Loss: 0.1035458070032682
# Epoch 36, Validation Accuracy: 0.9801
# Epoch [37/100], Reconstruction Loss: 0.047976114177516696, Classification Loss: 0.10204817632112778
# Epoch 37, Validation Accuracy: 0.9772
# Epoch [38/100], Reconstruction Loss: 0.04798424834373871, Classification Loss: 0.09989623032358107
# Epoch 38, Validation Accuracy: 0.9808
# Epoch [39/100], Reconstruction Loss: 0.04798170126490441, Classification Loss: 0.10150649612076307
# Epoch 39, Validation Accuracy: 0.9767
# Epoch [40/100], Reconstruction Loss: 0.04797265399098483, Classification Loss: 0.09778943035490556
# Epoch 40, Validation Accuracy: 0.9794
# Epoch [41/100], Reconstruction Loss: 0.047983759781582654, Classification Loss: 0.10168774875208815
# Epoch 41, Validation Accuracy: 0.9833
# Epoch [42/100], Reconstruction Loss: 0.04798267640770218, Classification Loss: 0.09841516320442699
# Epoch 42, Validation Accuracy: 0.9828
# Epoch [43/100], Reconstruction Loss: 0.04798240438082014, Classification Loss: 0.09286399825161608
# Epoch 43, Validation Accuracy: 0.9791
# Epoch [44/100], Reconstruction Loss: 0.04797802268993042, Classification Loss: 0.09570037298132482
# Epoch 44, Validation Accuracy: 0.9781
# Epoch [45/100], Reconstruction Loss: 0.04797316858576626, Classification Loss: 0.09514360647455783
# Epoch 45, Validation Accuracy: 0.9810
# Epoch [46/100], Reconstruction Loss: 0.04796861148347149, Classification Loss: 0.09675235964940285
# Epoch 46, Validation Accuracy: 0.9836
# Epoch [47/100], Reconstruction Loss: 0.04796599257568977, Classification Loss: 0.09516645731027508
# Epoch 47, Validation Accuracy: 0.9794
# Epoch [48/100], Reconstruction Loss: 0.047978929844961764, Classification Loss: 0.09280030868746052
# Epoch 48, Validation Accuracy: 0.9889
# Epoch [49/100], Reconstruction Loss: 0.04799079525089919, Classification Loss: 0.0940003933689363
# Epoch 49, Validation Accuracy: 0.9857
# Epoch [50/100], Reconstruction Loss: 0.047995180213264224, Classification Loss: 0.09708568959477014
# Epoch 50, Validation Accuracy: 0.9782
# Epoch [51/100], Reconstruction Loss: 0.048003697736173336, Classification Loss: 0.09134520223976993
# Epoch 51, Validation Accuracy: 0.9818
# Epoch [52/100], Reconstruction Loss: 0.048018896633030494, Classification Loss: 0.09124420019316683
# Epoch 52, Validation Accuracy: 0.9776
# Epoch [53/100], Reconstruction Loss: 0.04801816281311941, Classification Loss: 0.09820623596341418
# Epoch 53, Validation Accuracy: 0.9809
# Epoch [54/100], Reconstruction Loss: 0.047976689507689546, Classification Loss: 0.09565796127843681
# Epoch 54, Validation Accuracy: 0.9864
# Epoch [55/100], Reconstruction Loss: 0.047991556313247904, Classification Loss: 0.0923790369545119
# Epoch 55, Validation Accuracy: 0.9896
# Epoch [56/100], Reconstruction Loss: 0.0480059233065876, Classification Loss: 0.09590900655598128
# Epoch 56, Validation Accuracy: 0.9803
# Epoch [57/100], Reconstruction Loss: 0.04799619377274589, Classification Loss: 0.09844080564903204
# Epoch 57, Validation Accuracy: 0.9815
# Epoch [58/100], Reconstruction Loss: 0.047987237993992245, Classification Loss: 0.09160764502890235
# Epoch 58, Validation Accuracy: 0.9845
# Epoch [59/100], Reconstruction Loss: 0.04816851722893457, Classification Loss: 0.08948153379238001
# Epoch 59, Validation Accuracy: 0.9928
# Epoch [60/100], Reconstruction Loss: 0.04792532042158449, Classification Loss: 0.09057943442524204
# Epoch 60, Validation Accuracy: 0.9838
# Epoch [61/100], Reconstruction Loss: 0.04792610096115241, Classification Loss: 0.09055611281266493
# Epoch 61, Validation Accuracy: 0.9741
# Epoch [62/100], Reconstruction Loss: 0.047919987927110136, Classification Loss: 0.08890258475135172
# Epoch 62, Validation Accuracy: 0.9935
# Epoch [63/100], Reconstruction Loss: 0.04792381135354487, Classification Loss: 0.08900328626311142
# Epoch 63, Validation Accuracy: 0.9880
# Epoch [64/100], Reconstruction Loss: 0.047939334766564805, Classification Loss: 0.0889735288285358
# Epoch 64, Validation Accuracy: 0.9845
# Epoch [65/100], Reconstruction Loss: 0.04795129898448707, Classification Loss: 0.09389046834372763
# Epoch 65, Validation Accuracy: 0.9751
# Epoch [66/100], Reconstruction Loss: 0.04793518181250684, Classification Loss: 0.0865914172632437
# Epoch 66, Validation Accuracy: 0.9769
# Epoch [67/100], Reconstruction Loss: 0.047928584124641134, Classification Loss: 0.08698312874690081
# Epoch 67, Validation Accuracy: 0.9794
# Epoch [68/100], Reconstruction Loss: 0.047925371399953766, Classification Loss: 0.08511147762815692
# Epoch 68, Validation Accuracy: 0.9806
# Epoch [69/100], Reconstruction Loss: 0.04794035107601363, Classification Loss: 0.08831793123770623
# Epoch 69, Validation Accuracy: 0.9823
# Epoch [70/100], Reconstruction Loss: 0.04795190582122545, Classification Loss: 0.08543933696969304
# Epoch 70, Validation Accuracy: 0.9806
# Epoch [71/100], Reconstruction Loss: 0.047935278116053734, Classification Loss: 0.08338630457756263
# Epoch 71, Validation Accuracy: 0.9896
# Epoch [72/100], Reconstruction Loss: 0.04794837999452614, Classification Loss: 0.08576868476798596
# Epoch 72, Validation Accuracy: 0.9842
# Epoch [73/100], Reconstruction Loss: 0.047952390518372516, Classification Loss: 0.09430181896812924
# Epoch 73, Validation Accuracy: 0.9791
# Epoch [74/100], Reconstruction Loss: 0.04796691191007551, Classification Loss: 0.08402149084960733
# Epoch 74, Validation Accuracy: 0.9887
# Epoch [75/100], Reconstruction Loss: 0.04794892075352846, Classification Loss: 0.0845845993195985
# Epoch 75, Validation Accuracy: 0.9938
# Epoch [76/100], Reconstruction Loss: 0.047972581927006736, Classification Loss: 0.094634606645512
# Epoch 76, Validation Accuracy: 0.9778
# Epoch [77/100], Reconstruction Loss: 0.04794647040389568, Classification Loss: 0.08286497750054048
# Epoch 77, Validation Accuracy: 0.9890
# Epoch [78/100], Reconstruction Loss: 0.0479559770322657, Classification Loss: 0.08317304665503285
# Epoch 78, Validation Accuracy: 0.9913
# Epoch [79/100], Reconstruction Loss: 0.0479698527568058, Classification Loss: 0.08612747173534327
# Epoch 79, Validation Accuracy: 0.9745
# Epoch [80/100], Reconstruction Loss: 0.047960809418837645, Classification Loss: 0.08675119229679708
# Epoch 80, Validation Accuracy: 0.9842
# Epoch [81/100], Reconstruction Loss: 0.04798141510748018, Classification Loss: 0.08184137775875175
# Epoch 81, Validation Accuracy: 0.9852
# Epoch [82/100], Reconstruction Loss: 0.047979895063399884, Classification Loss: 0.0788638112076677
# Epoch 82, Validation Accuracy: 0.9954
# Epoch [83/100], Reconstruction Loss: 0.04799799445590354, Classification Loss: 0.08437767279995594
# Epoch 83, Validation Accuracy: 0.9812
# Epoch [84/100], Reconstruction Loss: 0.047993866161112, Classification Loss: 0.07739546029468497
# Epoch 84, Validation Accuracy: 0.9816
# Epoch [85/100], Reconstruction Loss: 0.04797182708538918, Classification Loss: 0.08365232504656242
# Epoch 85, Validation Accuracy: 0.9922
# Epoch [86/100], Reconstruction Loss: 0.04798176871329169, Classification Loss: 0.08978904888443681
# Epoch 86, Validation Accuracy: 0.9861
# Epoch [87/100], Reconstruction Loss: 0.047957691890778524, Classification Loss: 0.0873273080705972
# Epoch 87, Validation Accuracy: 0.9955
# Epoch [88/100], Reconstruction Loss: 0.04796617719607309, Classification Loss: 0.07954823085990846
# Epoch 88, Validation Accuracy: 0.9897
# Epoch [89/100], Reconstruction Loss: 0.04797742831631618, Classification Loss: 0.07906960568099436
# Epoch 89, Validation Accuracy: 0.9879
# Epoch [90/100], Reconstruction Loss: 0.04800159876985005, Classification Loss: 0.07835523787355732
# Epoch 90, Validation Accuracy: 0.9909
# Epoch [91/100], Reconstruction Loss: 0.048008838620538855, Classification Loss: 0.08091098403100258
# Epoch 91, Validation Accuracy: 0.9816
# Epoch [92/100], Reconstruction Loss: 0.04800621338100918, Classification Loss: 0.08105766612899383
# Epoch 92, Validation Accuracy: 0.9977
# Epoch [93/100], Reconstruction Loss: 0.048000139791503825, Classification Loss: 0.09163345951436819
# Epoch 93, Validation Accuracy: 0.9946
# Epoch [94/100], Reconstruction Loss: 0.04797572651283653, Classification Loss: 0.08205822624921688
# Epoch 94, Validation Accuracy: 0.9906
# Epoch [95/100], Reconstruction Loss: 0.04800042481059979, Classification Loss: 0.08505092553747946
# Epoch 95, Validation Accuracy: 0.9974
# Epoch [96/100], Reconstruction Loss: 0.048019692671084094, Classification Loss: 0.08199591942655193
# Epoch 96, Validation Accuracy: 0.9976
# Epoch [97/100], Reconstruction Loss: 0.04802431104273397, Classification Loss: 0.09201873009656854
# Epoch 97, Validation Accuracy: 0.9902
# Epoch [98/100], Reconstruction Loss: 0.04801950234389613, Classification Loss: 0.08209886538334053
# Epoch 98, Validation Accuracy: 0.9837
# Epoch [99/100], Reconstruction Loss: 0.04802178178236553, Classification Loss: 0.08392519688911748
# Epoch 99, Validation Accuracy: 0.9963
# Epoch [100/100], Reconstruction Loss: 0.04800818396426509, Classification Loss: 0.0793722488113791
# Epoch 100, Validation Accuracy: 0.9810

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9810482414594421
# Precision: 0.9816737556160047
# Recall: 0.9810482414594421
# F1 Score: 0.9810522465050886
# Confusion Matrix:
#  [[74283  2632     0     0     0]
#  [  139 66032     0     0     0]
#  [    0     0    19     0     0]
#  [    0     0     5  3626     0]
#  [    5     0     0     0     0]]
