# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the Model

# %%
import torch
import torch.nn as nn

class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dropout_rate=0.4):
        super(DeepAutoencoder, self).__init__()
        self.num_input_features = num_input_features

        # Adjust input size for Conv1d with dilation=3
        conv1d_output_size_dilated3 = (num_input_features - 3 * (3 - 1) - 1) + 1  # Adjusted for dilation=3

        # Dilated Encoder with dilation factor of 3
        self.encoder_dilated3 = nn.Sequential(
            nn.Linear(num_input_features, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Conv1d(in_channels=1, out_channels=1, kernel_size=3, stride=1, dilation=3),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(58, 32)  # Adjusted for conv1d_output_size_dilated3
        )

        # Dilated Decoder with adjusted input and output sizes for dilation=3
        self.decoder_dilated3 = nn.Sequential(
            nn.Linear(32, conv1d_output_size_dilated3),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Unflatten(dim=1, unflattened_size=(1, conv1d_output_size_dilated3)),  # Ensure correct input shape for ConvTranspose1d
            nn.ConvTranspose1d(1, 1, kernel_size=3, stride=1, dilation=3),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(49, num_input_features)
        )

        # Classifier
        self.classifier = nn.Linear(32, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        encoded_dilated3 = self.encoder_dilated3(x.unsqueeze(1))
        decoded = self.decoder_dilated3(encoded_dilated3)
        classification = self.classifier(encoded_dilated3)
        return decoded, classification

# Example usage
num_classes = len(label_encoder.classes_)  # Update this based on your dataset
num_input_features = 49  # Update this based on your dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes).to(device)

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.046804938811945834, Classification Loss: 0.26528459677001837
# Epoch 1, Validation Accuracy: 0.9070
# Epoch [2/100], Reconstruction Loss: 0.04131861045216861, Classification Loss: 0.18843118643959753
# Epoch 2, Validation Accuracy: 0.9636
# Epoch [3/100], Reconstruction Loss: 0.040654488293196005, Classification Loss: 0.15273818622303573
# Epoch 3, Validation Accuracy: 0.9761
# Epoch [4/100], Reconstruction Loss: 0.040600074983148715, Classification Loss: 0.14567136962975652
# Epoch 4, Validation Accuracy: 0.9640
# Epoch [5/100], Reconstruction Loss: 0.03947466512326152, Classification Loss: 0.12843409861688576
# Epoch 5, Validation Accuracy: 0.9705
# Epoch [6/100], Reconstruction Loss: 0.03903938799463987, Classification Loss: 0.1225605151786759
# Epoch 6, Validation Accuracy: 0.9682
# Epoch [7/100], Reconstruction Loss: 0.03908853867659996, Classification Loss: 0.11199154613051103
# Epoch 7, Validation Accuracy: 0.9701
# Epoch [8/100], Reconstruction Loss: 0.039028929623916395, Classification Loss: 0.11280307387883041
# Epoch 8, Validation Accuracy: 0.9796
# Epoch [9/100], Reconstruction Loss: 0.038809773883007784, Classification Loss: 0.10914929491111844
# Epoch 9, Validation Accuracy: 0.9750
# Epoch [10/100], Reconstruction Loss: 0.03857421576879298, Classification Loss: 0.10480496271190912
# Epoch 10, Validation Accuracy: 0.9803
# Epoch [11/100], Reconstruction Loss: 0.03856236325461281, Classification Loss: 0.10168968404053359
# Epoch 11, Validation Accuracy: 0.9733
# Epoch [12/100], Reconstruction Loss: 0.03861239634487826, Classification Loss: 0.10337923154186689
# Epoch 12, Validation Accuracy: 0.9700
# Epoch [13/100], Reconstruction Loss: 0.038533406277709896, Classification Loss: 0.10209662399392427
# Epoch 13, Validation Accuracy: 0.9814
# Epoch [14/100], Reconstruction Loss: 0.03855841380787296, Classification Loss: 0.09862462880147012
# Epoch 14, Validation Accuracy: 0.9722
# Epoch [15/100], Reconstruction Loss: 0.0386234863556576, Classification Loss: 0.09853899305875083
# Epoch 15, Validation Accuracy: 0.9721
# Epoch [16/100], Reconstruction Loss: 0.03835785961035016, Classification Loss: 0.09640329986849135
# Epoch 16, Validation Accuracy: 0.9847
# Epoch [17/100], Reconstruction Loss: 0.03846012750893142, Classification Loss: 0.09627402811914332
# Epoch 17, Validation Accuracy: 0.9678
# Epoch [18/100], Reconstruction Loss: 0.03836670465174933, Classification Loss: 0.09475325477063257
# Epoch 18, Validation Accuracy: 0.9804
# Epoch [19/100], Reconstruction Loss: 0.038279330311065535, Classification Loss: 0.09411129060813023
# Epoch 19, Validation Accuracy: 0.9844
# Epoch [20/100], Reconstruction Loss: 0.038327741623628814, Classification Loss: 0.09252668808484191
# Epoch 20, Validation Accuracy: 0.9863
# Epoch [21/100], Reconstruction Loss: 0.03833130022113121, Classification Loss: 0.09079062151842596
# Epoch 21, Validation Accuracy: 0.9867
# Epoch [22/100], Reconstruction Loss: 0.03838342407899448, Classification Loss: 0.09121636027297748
# Epoch 22, Validation Accuracy: 0.9783
# Epoch [23/100], Reconstruction Loss: 0.038370849373776786, Classification Loss: 0.09067200550157008
# Epoch 23, Validation Accuracy: 0.9871
# Epoch [24/100], Reconstruction Loss: 0.03846783675377947, Classification Loss: 0.09150781753807861
# Epoch 24, Validation Accuracy: 0.9759
# Epoch [25/100], Reconstruction Loss: 0.03821965617140308, Classification Loss: 0.08978342976559077
# Epoch 25, Validation Accuracy: 0.9761
# Epoch [26/100], Reconstruction Loss: 0.03810564295699741, Classification Loss: 0.08847850711359873
# Epoch 26, Validation Accuracy: 0.9781
# Epoch [27/100], Reconstruction Loss: 0.03814898886090882, Classification Loss: 0.08799235423315933
# Epoch 27, Validation Accuracy: 0.9770
# Epoch [28/100], Reconstruction Loss: 0.03822350262136658, Classification Loss: 0.08842700065562004
# Epoch 28, Validation Accuracy: 0.9782
# Epoch [29/100], Reconstruction Loss: 0.038402719574536774, Classification Loss: 0.0890712399655897
# Epoch 29, Validation Accuracy: 0.9888
# Epoch [30/100], Reconstruction Loss: 0.03884195543929603, Classification Loss: 0.08724299529329081
# Epoch 30, Validation Accuracy: 0.9886
# Epoch [31/100], Reconstruction Loss: 0.03875712220311849, Classification Loss: 0.08674600515992525
# Epoch 31, Validation Accuracy: 0.9899
# Epoch [32/100], Reconstruction Loss: 0.038900542773305284, Classification Loss: 0.08755755733701585
# Epoch 32, Validation Accuracy: 0.9887
# Epoch [33/100], Reconstruction Loss: 0.039093420735063084, Classification Loss: 0.0886715709440695
# Epoch 33, Validation Accuracy: 0.9866
# Epoch [34/100], Reconstruction Loss: 0.03914047762245776, Classification Loss: 0.0859452575077229
# Epoch 34, Validation Accuracy: 0.9875
# Epoch [35/100], Reconstruction Loss: 0.03910178752803693, Classification Loss: 0.08506759916850411
# Epoch 35, Validation Accuracy: 0.9846
# Epoch [36/100], Reconstruction Loss: 0.039003817366468886, Classification Loss: 0.0832385481203898
# Epoch 36, Validation Accuracy: 0.9809
# Epoch [37/100], Reconstruction Loss: 0.038889022144636694, Classification Loss: 0.08405704956021033
# Epoch 37, Validation Accuracy: 0.9779
# Epoch [38/100], Reconstruction Loss: 0.039174729205970156, Classification Loss: 0.08814195916139557
# Epoch 38, Validation Accuracy: 0.9721
# Epoch [39/100], Reconstruction Loss: 0.03903028773592558, Classification Loss: 0.08376230759207559
# Epoch 39, Validation Accuracy: 0.9892
# Epoch [40/100], Reconstruction Loss: 0.03909646293958279, Classification Loss: 0.08205016832614594
# Epoch 40, Validation Accuracy: 0.9883
# Epoch [41/100], Reconstruction Loss: 0.03900430945706352, Classification Loss: 0.08313097820364357
# Epoch 41, Validation Accuracy: 0.9903
# Epoch [42/100], Reconstruction Loss: 0.03901667452656542, Classification Loss: 0.08553202703738942
# Epoch 42, Validation Accuracy: 0.9880
# Epoch [43/100], Reconstruction Loss: 0.03893159289464846, Classification Loss: 0.08108686237598818
# Epoch 43, Validation Accuracy: 0.9874
# Epoch [44/100], Reconstruction Loss: 0.039104991849023926, Classification Loss: 0.08158543286557392
# Epoch 44, Validation Accuracy: 0.9875
# Epoch [45/100], Reconstruction Loss: 0.03894813121289019, Classification Loss: 0.08092075915307756
# Epoch 45, Validation Accuracy: 0.9821
# Epoch [46/100], Reconstruction Loss: 0.03886552137959175, Classification Loss: 0.079242347097453
# Epoch 46, Validation Accuracy: 0.9753
# Epoch [47/100], Reconstruction Loss: 0.038955468967392326, Classification Loss: 0.0790714637869445
# Epoch 47, Validation Accuracy: 0.9889
# Epoch [48/100], Reconstruction Loss: 0.03884671833910409, Classification Loss: 0.0767351467823936
# Epoch 48, Validation Accuracy: 0.9883
# Epoch [49/100], Reconstruction Loss: 0.03895678813037856, Classification Loss: 0.07713881226145879
# Epoch 49, Validation Accuracy: 0.9816
# Epoch [50/100], Reconstruction Loss: 0.03885302397536623, Classification Loss: 0.07583317635186246
# Epoch 50, Validation Accuracy: 0.9880
# Epoch [51/100], Reconstruction Loss: 0.0389291608987991, Classification Loss: 0.07618017594650726
# Epoch 51, Validation Accuracy: 0.9913
# Epoch [52/100], Reconstruction Loss: 0.03876197935076738, Classification Loss: 0.07507974884125793
# Epoch 52, Validation Accuracy: 0.9815
# Epoch [53/100], Reconstruction Loss: 0.03890988261140108, Classification Loss: 0.0812884692973137
# Epoch 53, Validation Accuracy: 0.9883
# Epoch [54/100], Reconstruction Loss: 0.03884836607605223, Classification Loss: 0.07398988459558847
# Epoch 54, Validation Accuracy: 0.9877
# Epoch [55/100], Reconstruction Loss: 0.03887012066420583, Classification Loss: 0.07650732635464891
# Epoch 55, Validation Accuracy: 0.9939
# Epoch [56/100], Reconstruction Loss: 0.03891258387468828, Classification Loss: 0.07944947480599042
# Epoch 56, Validation Accuracy: 0.9917
# Epoch [57/100], Reconstruction Loss: 0.03889273316061268, Classification Loss: 0.07280050084338544
# Epoch 57, Validation Accuracy: 0.9933
# Epoch [58/100], Reconstruction Loss: 0.03890402794782159, Classification Loss: 0.07838393799119661
# Epoch 58, Validation Accuracy: 0.9688
# Epoch [59/100], Reconstruction Loss: 0.03899753723942856, Classification Loss: 0.07412317871665229
# Epoch 59, Validation Accuracy: 0.9857
# Epoch [60/100], Reconstruction Loss: 0.03886596032617735, Classification Loss: 0.07242561029142013
# Epoch 60, Validation Accuracy: 0.9783
# Epoch [61/100], Reconstruction Loss: 0.03886627923572136, Classification Loss: 0.077097348877207
# Epoch 61, Validation Accuracy: 0.9877
# Epoch [62/100], Reconstruction Loss: 0.038934394235782696, Classification Loss: 0.07451508444755782
# Epoch 62, Validation Accuracy: 0.9898
# Epoch [63/100], Reconstruction Loss: 0.03894861115635238, Classification Loss: 0.07204343211786393
# Epoch 63, Validation Accuracy: 0.9876
# Epoch [64/100], Reconstruction Loss: 0.039034911348380344, Classification Loss: 0.07058298059926073
# Epoch 64, Validation Accuracy: 0.9912
# Epoch [65/100], Reconstruction Loss: 0.03903610282905886, Classification Loss: 0.07203021905843528
# Epoch 65, Validation Accuracy: 0.9949
# Epoch [66/100], Reconstruction Loss: 0.03901863971765451, Classification Loss: 0.07193490199108114
# Epoch 66, Validation Accuracy: 0.9742
# Epoch [67/100], Reconstruction Loss: 0.0390130950495122, Classification Loss: 0.07077008307102725
# Epoch 67, Validation Accuracy: 0.9937
# Epoch [68/100], Reconstruction Loss: 0.03891433837513129, Classification Loss: 0.07457894032332078
# Epoch 68, Validation Accuracy: 0.9770
# Epoch [69/100], Reconstruction Loss: 0.03922523775841022, Classification Loss: 0.08181930010545531
# Epoch 69, Validation Accuracy: 0.9867
# Epoch [70/100], Reconstruction Loss: 0.03924378157604276, Classification Loss: 0.0736310760017455
# Epoch 70, Validation Accuracy: 0.9879
# Epoch [71/100], Reconstruction Loss: 0.039230766848188915, Classification Loss: 0.07292615629626736
# Epoch 71, Validation Accuracy: 0.9954
# Epoch [72/100], Reconstruction Loss: 0.03909711152432114, Classification Loss: 0.06949375930700286
# Epoch 72, Validation Accuracy: 0.9929
# Epoch [73/100], Reconstruction Loss: 0.03924923235511802, Classification Loss: 0.07056024425701402
# Epoch 73, Validation Accuracy: 0.9812
# Epoch [74/100], Reconstruction Loss: 0.03931182164193577, Classification Loss: 0.06965590879267926
# Epoch 74, Validation Accuracy: 0.9703
# Epoch [75/100], Reconstruction Loss: 0.039224532745190444, Classification Loss: 0.0702159418869256
# Epoch 75, Validation Accuracy: 0.9962
# Epoch [76/100], Reconstruction Loss: 0.03931753492346465, Classification Loss: 0.0706159468372744
# Epoch 76, Validation Accuracy: 0.9838
# Epoch [77/100], Reconstruction Loss: 0.03935871812550026, Classification Loss: 0.06973598070920184
# Epoch 77, Validation Accuracy: 0.9903
# Epoch [78/100], Reconstruction Loss: 0.03940078946891081, Classification Loss: 0.07963180488203198
# Epoch 78, Validation Accuracy: 0.9824
# Epoch [79/100], Reconstruction Loss: 0.03914104930830133, Classification Loss: 0.07018839130469852
# Epoch 79, Validation Accuracy: 0.9836
# Epoch [80/100], Reconstruction Loss: 0.039489727687436686, Classification Loss: 0.0750214551223782
# Epoch 80, Validation Accuracy: 0.9786
# Epoch [81/100], Reconstruction Loss: 0.03932109070628522, Classification Loss: 0.07213064515274419
# Epoch 81, Validation Accuracy: 0.9854
# Epoch [82/100], Reconstruction Loss: 0.03985998376354798, Classification Loss: 0.08432145031836646
# Epoch 82, Validation Accuracy: 0.9971
# Epoch [83/100], Reconstruction Loss: 0.03929795993989958, Classification Loss: 0.07224756814790828
# Epoch 83, Validation Accuracy: 0.9925
# Epoch [84/100], Reconstruction Loss: 0.03923349118943018, Classification Loss: 0.07049077905717456
# Epoch 84, Validation Accuracy: 0.9972
# Epoch [85/100], Reconstruction Loss: 0.039361796263989314, Classification Loss: 0.07434351027175622
# Epoch 85, Validation Accuracy: 0.9886
# Epoch [86/100], Reconstruction Loss: 0.0394066602261343, Classification Loss: 0.07703692304937927
# Epoch 86, Validation Accuracy: 0.9844
# Epoch [87/100], Reconstruction Loss: 0.03924757874132, Classification Loss: 0.0786534469044957
# Epoch 87, Validation Accuracy: 0.9816
# Epoch [88/100], Reconstruction Loss: 0.03913031902252493, Classification Loss: 0.06770132452255011
# Epoch 88, Validation Accuracy: 0.9984
# Epoch [89/100], Reconstruction Loss: 0.03929743262638462, Classification Loss: 0.07169314862009875
# Epoch 89, Validation Accuracy: 0.9978
# Epoch [90/100], Reconstruction Loss: 0.03914581906596863, Classification Loss: 0.07271884994786858
# Epoch 90, Validation Accuracy: 0.9958
# Epoch [91/100], Reconstruction Loss: 0.03928299082261971, Classification Loss: 0.07131904316378988
# Epoch 91, Validation Accuracy: 0.9755
# Epoch [92/100], Reconstruction Loss: 0.03929423711904781, Classification Loss: 0.07388217915049891
# Epoch 92, Validation Accuracy: 0.9965
# Epoch [93/100], Reconstruction Loss: 0.03933221816979777, Classification Loss: 0.07512973930892981
# Epoch 93, Validation Accuracy: 0.9915
# Epoch [94/100], Reconstruction Loss: 0.039481867837208806, Classification Loss: 0.07935333405608996
# Epoch 94, Validation Accuracy: 0.9941
# Epoch [95/100], Reconstruction Loss: 0.039578595736039245, Classification Loss: 0.08407834031988601
# Epoch 95, Validation Accuracy: 0.9953
# Epoch [96/100], Reconstruction Loss: 0.03935085326597811, Classification Loss: 0.07405231058573399
# Epoch 96, Validation Accuracy: 0.9887
# Epoch [97/100], Reconstruction Loss: 0.03933025304152792, Classification Loss: 0.08199685166809513
# Epoch 97, Validation Accuracy: 0.9980
# Epoch [98/100], Reconstruction Loss: 0.039738722104670735, Classification Loss: 0.08191140474517238
# Epoch 98, Validation Accuracy: 0.9964
# Epoch [99/100], Reconstruction Loss: 0.03952131764309353, Classification Loss: 0.08878825476461068
# Epoch 99, Validation Accuracy: 0.9828
# Epoch [100/100], Reconstruction Loss: 0.04015376769262945, Classification Loss: 0.08899274108417835
# Epoch 100, Validation Accuracy: 0.9727

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9727547174954512
# Precision: 0.9738013605440103
# Recall: 0.9727547174954512
# F1 Score: 0.9727721286131561
# Confusion Matrix:
#  [[73298  3617     0     0     0]
#  [  371 65799     1     0     0]
#  [    0     0    19     0     0]
#  [    0     0     4  3627     0]
#  [    5     0     0     0     0]]
