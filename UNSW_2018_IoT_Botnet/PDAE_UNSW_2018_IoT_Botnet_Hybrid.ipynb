# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the PDAE Model

# %%
import torch
import torch.nn as nn

class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dropout_rate=0.5):
        super(DeepAutoencoder, self).__init__()
        self.num_input_features = num_input_features

        # Hybrid Encoder
        self.encoder_hybrid = nn.Sequential(
            nn.Linear(num_input_features, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, stride=1, dilation=3),  # Dilated Conv layer
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(1856, 32)  # Adjust the size according to the Conv1d output
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(32, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, num_input_features)
        )

        # Classifier
        self.classifier = nn.Linear(32, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        x = x.unsqueeze(1)  # Adding channel dimension for Conv1d
        encoded_hybrid = self.encoder_hybrid(x)
        decoded = self.decoder(encoded_hybrid)
        classification = self.classifier(encoded_hybrid)
        return decoded, classification


# Example usage
num_classes = len(label_encoder.classes_)
print(num_classes)  # Update this based on your dataset
num_input_features = 49  # Update this based on your dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes).to(device)
# Out:
# 5

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.048492823374476746, Classification Loss: 0.509949154123991
# Epoch 1, Validation Accuracy: 0.9121
# Epoch [2/100], Reconstruction Loss: 0.04793328279121651, Classification Loss: 0.37216025303985895
# Epoch 2, Validation Accuracy: 0.8288
# Epoch [3/100], Reconstruction Loss: 0.0479393230529394, Classification Loss: 0.3702305202949253
# Epoch 3, Validation Accuracy: 0.8231
# Epoch [4/100], Reconstruction Loss: 0.04801665627626264, Classification Loss: 0.3508496107941087
# Epoch 4, Validation Accuracy: 0.9101
# Epoch [5/100], Reconstruction Loss: 0.04805107368366163, Classification Loss: 0.33468535709067443
# Epoch 5, Validation Accuracy: 0.9126
# Epoch [6/100], Reconstruction Loss: 0.04802521327945066, Classification Loss: 0.3265804901929213
# Epoch 6, Validation Accuracy: 0.8671
# Epoch [7/100], Reconstruction Loss: 0.048029872321696074, Classification Loss: 0.3224655354487842
# Epoch 7, Validation Accuracy: 0.9166
# Epoch [8/100], Reconstruction Loss: 0.048026419336092405, Classification Loss: 0.32037344141475405
# Epoch 8, Validation Accuracy: 0.6689
# Epoch [9/100], Reconstruction Loss: 0.048036606693435915, Classification Loss: 0.3094652054200756
# Epoch 9, Validation Accuracy: 0.8459
# Epoch [10/100], Reconstruction Loss: 0.0480339867881277, Classification Loss: 0.3133532036486312
# Epoch 10, Validation Accuracy: 0.8916
# Epoch [11/100], Reconstruction Loss: 0.04804432851675725, Classification Loss: 0.30248890278219465
# Epoch 11, Validation Accuracy: 0.8279
# Epoch [12/100], Reconstruction Loss: 0.048046691118717746, Classification Loss: 0.30765024924940243
# Epoch 12, Validation Accuracy: 0.8093
# Epoch [13/100], Reconstruction Loss: 0.04801393594570606, Classification Loss: 0.2992158588858681
# Epoch 13, Validation Accuracy: 0.8157
# Epoch [14/100], Reconstruction Loss: 0.04805007279850678, Classification Loss: 0.2979322985737437
# Epoch 14, Validation Accuracy: 0.8152
# Epoch [15/100], Reconstruction Loss: 0.04803492465960995, Classification Loss: 0.2955085434705162
# Epoch 15, Validation Accuracy: 0.9275
# Epoch [16/100], Reconstruction Loss: 0.048007653338117365, Classification Loss: 0.2949622329256791
# Epoch 16, Validation Accuracy: 0.9139
# Epoch [17/100], Reconstruction Loss: 0.047996185191960195, Classification Loss: 0.2956500899879015
# Epoch 17, Validation Accuracy: 0.8574
# Epoch [18/100], Reconstruction Loss: 0.0480121701916804, Classification Loss: 0.29498859498607055
# Epoch 18, Validation Accuracy: 0.9187
# Epoch [19/100], Reconstruction Loss: 0.04803937940442262, Classification Loss: 0.2975344086578461
# Epoch 19, Validation Accuracy: 0.9256
# Epoch [20/100], Reconstruction Loss: 0.048035587207823756, Classification Loss: 0.29082162309720133
# Epoch 20, Validation Accuracy: 0.8405
# Epoch [21/100], Reconstruction Loss: 0.04801346848811291, Classification Loss: 0.712266535531913
# Epoch 21, Validation Accuracy: 0.5255
# Epoch [22/100], Reconstruction Loss: 0.04801105016601226, Classification Loss: 0.7909717261834552
# Epoch 22, Validation Accuracy: 0.5255
# Epoch [23/100], Reconstruction Loss: 0.04803103199552218, Classification Loss: 0.7909156567205747
# Epoch 23, Validation Accuracy: 0.5255
# Epoch [24/100], Reconstruction Loss: 0.04803909208917448, Classification Loss: 0.7909636568461658
# Epoch 24, Validation Accuracy: 0.5255
# Epoch [25/100], Reconstruction Loss: 0.04801129286550716, Classification Loss: 0.7909493157208217
# Epoch 25, Validation Accuracy: 0.5255
# Epoch [26/100], Reconstruction Loss: 0.04800521586264162, Classification Loss: 0.7910175665136443
# Epoch 26, Validation Accuracy: 0.5255
# Epoch [27/100], Reconstruction Loss: 0.048031419122447835, Classification Loss: 0.7909613180895291
# Epoch 27, Validation Accuracy: 0.5255
# Epoch [28/100], Reconstruction Loss: 0.04804487669709672, Classification Loss: 0.7909987605333779
# Epoch 28, Validation Accuracy: 0.5255
# Epoch [29/100], Reconstruction Loss: 0.04803547907367767, Classification Loss: 0.7910121175798848
# Epoch 29, Validation Accuracy: 0.5255
# Epoch [30/100], Reconstruction Loss: 0.04802570009024914, Classification Loss: 0.790938868167737
# Epoch 30, Validation Accuracy: 0.5255
# Epoch [31/100], Reconstruction Loss: 0.04803418915820063, Classification Loss: 0.7909150331203008
# Epoch 31, Validation Accuracy: 0.5255
# Epoch [32/100], Reconstruction Loss: 0.04803449681226658, Classification Loss: 0.7909253555027651
# Epoch 32, Validation Accuracy: 0.5255
# Epoch [33/100], Reconstruction Loss: 0.04803788619553788, Classification Loss: 0.7909921230072718
# Epoch 33, Validation Accuracy: 0.5255
# Epoch [34/100], Reconstruction Loss: 0.04803626365858917, Classification Loss: 0.7909109844494601
# Epoch 34, Validation Accuracy: 0.5255
# Epoch [35/100], Reconstruction Loss: 0.04803115038978601, Classification Loss: 0.7908575177920525
# Epoch 35, Validation Accuracy: 0.5255
# Epoch [36/100], Reconstruction Loss: 0.048039155029196916, Classification Loss: 0.7909101627995618
# Epoch 36, Validation Accuracy: 0.5255
# Epoch [37/100], Reconstruction Loss: 0.048044571351096944, Classification Loss: 0.7909663877855954
# Epoch 37, Validation Accuracy: 0.5255
# Epoch [38/100], Reconstruction Loss: 0.04802753111564986, Classification Loss: 0.7909462142864065
# Epoch 38, Validation Accuracy: 0.5255
# Epoch [39/100], Reconstruction Loss: 0.04802697742508671, Classification Loss: 0.7909633342151223
# Epoch 39, Validation Accuracy: 0.5255
# Epoch [40/100], Reconstruction Loss: 0.04801526604168012, Classification Loss: 0.7909457857637562
# Epoch 40, Validation Accuracy: 0.5255
# Epoch [41/100], Reconstruction Loss: 0.04800822958025255, Classification Loss: 0.7909125547749408
# Epoch 41, Validation Accuracy: 0.5255
# Epoch [42/100], Reconstruction Loss: 0.0480124161480289, Classification Loss: 0.7909887641785294
# Epoch 42, Validation Accuracy: 0.5255
# Epoch [43/100], Reconstruction Loss: 0.048020273633328336, Classification Loss: 0.7909214670600231
# Epoch 43, Validation Accuracy: 0.5255
# Epoch [44/100], Reconstruction Loss: 0.04802177212769546, Classification Loss: 0.7909566473434061
# Epoch 44, Validation Accuracy: 0.5255
# Epoch [45/100], Reconstruction Loss: 0.048019684670293446, Classification Loss: 0.7909634161400992
# Epoch 45, Validation Accuracy: 0.5255
# Epoch [46/100], Reconstruction Loss: 0.048013476384926854, Classification Loss: 0.790913407583191
# Epoch 46, Validation Accuracy: 0.5255
# Epoch [47/100], Reconstruction Loss: 0.048026739664485174, Classification Loss: 0.791030120955319
# Epoch 47, Validation Accuracy: 0.5255
# Epoch [48/100], Reconstruction Loss: 0.04803614890188529, Classification Loss: 0.7908896431272712
# Epoch 48, Validation Accuracy: 0.5255
# Epoch [49/100], Reconstruction Loss: 0.04799853796541457, Classification Loss: 0.7909330642228557
# Epoch 49, Validation Accuracy: 0.5255
# Epoch [50/100], Reconstruction Loss: 0.04798732317311505, Classification Loss: 0.7910586672997921
# Epoch 50, Validation Accuracy: 0.5255
# Epoch [51/100], Reconstruction Loss: 0.047984542423971065, Classification Loss: 0.7909806308869031
# Epoch 51, Validation Accuracy: 0.5255
# Epoch [52/100], Reconstruction Loss: 0.04799594387448896, Classification Loss: 0.7909264318522611
# Epoch 52, Validation Accuracy: 0.5255
# Epoch [53/100], Reconstruction Loss: 0.04803707296829408, Classification Loss: 0.790984845383255
# Epoch 53, Validation Accuracy: 0.5255
# Epoch [54/100], Reconstruction Loss: 0.0480357790307599, Classification Loss: 0.7909602871431932
# Epoch 54, Validation Accuracy: 0.5255
# Epoch [55/100], Reconstruction Loss: 0.048044870357225586, Classification Loss: 0.7910019601824534
# Epoch 55, Validation Accuracy: 0.5255
# Epoch [56/100], Reconstruction Loss: 0.048040972022075155, Classification Loss: 0.7909340620006234
# Epoch 56, Validation Accuracy: 0.5255
# Epoch [57/100], Reconstruction Loss: 0.04800993922964087, Classification Loss: 0.7909453023760658
# Epoch 57, Validation Accuracy: 0.5255
# Epoch [58/100], Reconstruction Loss: 0.04803392134075041, Classification Loss: 0.7910262873776172
# Epoch 58, Validation Accuracy: 0.5255
# Epoch [59/100], Reconstruction Loss: 0.048004564758905195, Classification Loss: 0.7909474706022455
# Epoch 59, Validation Accuracy: 0.5255
# Epoch [60/100], Reconstruction Loss: 0.048016396474224794, Classification Loss: 0.790949300262952
# Epoch 60, Validation Accuracy: 0.5255
# Epoch [61/100], Reconstruction Loss: 0.04803586451314809, Classification Loss: 0.7909633691772886
# Epoch 61, Validation Accuracy: 0.5255
# Epoch [62/100], Reconstruction Loss: 0.04803753792611401, Classification Loss: 0.7909624590865401
# Epoch 62, Validation Accuracy: 0.5255
# Epoch [63/100], Reconstruction Loss: 0.04801679379682431, Classification Loss: 0.7909529116424403
# Epoch 63, Validation Accuracy: 0.5255
# Epoch [64/100], Reconstruction Loss: 0.048019876292857824, Classification Loss: 0.7908919446775777
# Epoch 64, Validation Accuracy: 0.5255
# Epoch [65/100], Reconstruction Loss: 0.048059553836152416, Classification Loss: 0.7908801709882983
# Epoch 65, Validation Accuracy: 0.5255
# Epoch [66/100], Reconstruction Loss: 0.048045065751111615, Classification Loss: 0.7909088346618156
# Epoch 66, Validation Accuracy: 0.5255
# Epoch [67/100], Reconstruction Loss: 0.04803682401611684, Classification Loss: 0.7909525455924588
# Epoch 67, Validation Accuracy: 0.5255
# Epoch [68/100], Reconstruction Loss: 0.048006869577979394, Classification Loss: 0.7910542090993787
# Epoch 68, Validation Accuracy: 0.5255
# Epoch [69/100], Reconstruction Loss: 0.0480080294716729, Classification Loss: 0.7909183363215073
# Epoch 69, Validation Accuracy: 0.5255
# Epoch [70/100], Reconstruction Loss: 0.04799937969852125, Classification Loss: 0.7909162923041636
# Epoch 70, Validation Accuracy: 0.5255
# Epoch [71/100], Reconstruction Loss: 0.04800286544220169, Classification Loss: 0.7909575055324506
# Epoch 71, Validation Accuracy: 0.5255
# Epoch [72/100], Reconstruction Loss: 0.04799043016324367, Classification Loss: 0.7909774847598352
# Epoch 72, Validation Accuracy: 0.5255
# Epoch [73/100], Reconstruction Loss: 0.04800036645096772, Classification Loss: 0.7909236320889192
# Epoch 73, Validation Accuracy: 0.5255
# Epoch [74/100], Reconstruction Loss: 0.047997630258548536, Classification Loss: 0.7909113801241372
# Epoch 74, Validation Accuracy: 0.5255
# Epoch [75/100], Reconstruction Loss: 0.04800419772114496, Classification Loss: 0.7909464539093825
# Epoch 75, Validation Accuracy: 0.5255
# Epoch [76/100], Reconstruction Loss: 0.0480183405585848, Classification Loss: 0.7909141920874122
# Epoch 76, Validation Accuracy: 0.5255
# Epoch [77/100], Reconstruction Loss: 0.04800069423210727, Classification Loss: 0.7909976432257257
# Epoch 77, Validation Accuracy: 0.5255
# Epoch [78/100], Reconstruction Loss: 0.04801598248773405, Classification Loss: 0.7910033274067749
# Epoch 78, Validation Accuracy: 0.5255
# Epoch [79/100], Reconstruction Loss: 0.04804501890744091, Classification Loss: 0.7909391770825204
# Epoch 79, Validation Accuracy: 0.5255
# Epoch [80/100], Reconstruction Loss: 0.0480330696058431, Classification Loss: 0.7909439267209665
# Epoch 80, Validation Accuracy: 0.5255
# Epoch [81/100], Reconstruction Loss: 0.04803191032842818, Classification Loss: 0.7909043778217641
# Epoch 81, Validation Accuracy: 0.5255
# Epoch [82/100], Reconstruction Loss: 0.04804495766732925, Classification Loss: 0.790953394770189
# Epoch 82, Validation Accuracy: 0.5255
# Epoch [83/100], Reconstruction Loss: 0.048034598584879726, Classification Loss: 0.7909295601213302
# Epoch 83, Validation Accuracy: 0.5255
# Epoch [84/100], Reconstruction Loss: 0.04803037300634426, Classification Loss: 0.7909649650117203
# Epoch 84, Validation Accuracy: 0.5255
# Epoch [85/100], Reconstruction Loss: 0.04802225389020841, Classification Loss: 0.7909813295843504
# Epoch 85, Validation Accuracy: 0.5255
# Epoch [86/100], Reconstruction Loss: 0.04802155171333227, Classification Loss: 0.7909536685668412
# Epoch 86, Validation Accuracy: 0.5255
# Epoch [87/100], Reconstruction Loss: 0.048013006582983984, Classification Loss: 0.7909001904286727
# Epoch 87, Validation Accuracy: 0.5255
# Epoch [88/100], Reconstruction Loss: 0.048015602617515765, Classification Loss: 0.7909077817330719
# Epoch 88, Validation Accuracy: 0.5255
# Epoch [89/100], Reconstruction Loss: 0.04802838715151015, Classification Loss: 0.7908675636658057
# Epoch 89, Validation Accuracy: 0.5255
# Epoch [90/100], Reconstruction Loss: 0.048010158745580366, Classification Loss: 0.7909830345596611
# Epoch 90, Validation Accuracy: 0.5255
# Epoch [91/100], Reconstruction Loss: 0.04801435452504272, Classification Loss: 0.7909396189748418
# Epoch 91, Validation Accuracy: 0.5255
# Epoch [92/100], Reconstruction Loss: 0.04803470865667499, Classification Loss: 0.7908927695247596
# Epoch 92, Validation Accuracy: 0.5255
# Epoch [93/100], Reconstruction Loss: 0.048018999988039074, Classification Loss: 0.7910216724669834
# Epoch 93, Validation Accuracy: 0.5255
# Epoch [94/100], Reconstruction Loss: 0.048022714681378594, Classification Loss: 0.7909218928012968
# Epoch 94, Validation Accuracy: 0.5255
# Epoch [95/100], Reconstruction Loss: 0.048015273441355456, Classification Loss: 0.7909387242899747
# Epoch 95, Validation Accuracy: 0.5255
# Epoch [96/100], Reconstruction Loss: 0.04801939948602616, Classification Loss: 0.7909800513640862
# Epoch 96, Validation Accuracy: 0.5255
# Epoch [97/100], Reconstruction Loss: 0.04802358469831457, Classification Loss: 0.7908811679862409
# Epoch 97, Validation Accuracy: 0.5255
# Epoch [98/100], Reconstruction Loss: 0.04803730035288716, Classification Loss: 0.7909322097509783
# Epoch 98, Validation Accuracy: 0.5255
# Epoch [99/100], Reconstruction Loss: 0.048027489249863796, Classification Loss: 0.7909136595880591
# Epoch 99, Validation Accuracy: 0.5255
# Epoch [100/100], Reconstruction Loss: 0.04802710060661122, Classification Loss: 0.7909310511819047
# Epoch 100, Validation Accuracy: 0.5255

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.5241548033610238
# Precision: 0.7505834545254096
# Recall: 0.5241548033610238
# F1 Score: 0.3605122751056368
# Confusion Matrix:
#  [[76915     0     0     0     0]
#  [66171     0     0     0     0]
#  [   19     0     0     0     0]
#  [ 3631     0     0     0     0]
#  [    5     0     0     0     0]]
