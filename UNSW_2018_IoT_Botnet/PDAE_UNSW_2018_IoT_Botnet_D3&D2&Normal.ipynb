# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the PDAE Model

# %%
import torch
import torch.nn as nn

KERNEL = 3
HIDDEN = 64   # linear layer width before the conv layer
LATENT = 32   # latent size per branch


class ConvEncoder(nn.Module):
    def __init__(self, n_in, dilation, dropout, latent=LATENT):
        super().__init__()
        conv_len = HIDDEN - dilation * (KERNEL - 1)
        self.net = nn.Sequential(
            nn.Linear(n_in, HIDDEN),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Conv1d(1, 1, kernel_size=KERNEL, stride=1, dilation=dilation),
            nn.Flatten(),
            nn.Linear(conv_len, latent),
        )

    def forward(self, x):
        return self.net(x.unsqueeze(1))


class ConvDecoder(nn.Module):
    def __init__(self, n_out, dilation, dropout, latent=LATENT):
        super().__init__()
        mid = n_out - dilation * (KERNEL - 1)
        self.net = nn.Sequential(
            nn.Linear(latent, mid),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Unflatten(dim=1, unflattened_size=(1, mid)),
            nn.ConvTranspose1d(1, 1, kernel_size=KERNEL, stride=1, dilation=dilation),
            nn.Flatten(),
            nn.Linear(n_out, n_out),
        )

    def forward(self, z):
        return self.net(z)


class SharedDecoder(nn.Module):
    def __init__(self, n_out, in_dim, dropout):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, n_out),
        )

    def forward(self, z):
        return self.net(z)


class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dilations=(1,), dropout_rate=0.4):
        super().__init__()
        self.num_input_features = num_input_features
        self.dilations = tuple(dilations)
        self.encoders = nn.ModuleList(
            [ConvEncoder(num_input_features, d, dropout_rate) for d in self.dilations]
        )
        latent_total = LATENT * len(self.dilations)
        if len(self.dilations) == 1:
            self.decoder = ConvDecoder(num_input_features, self.dilations[0], dropout_rate)
        else:
            self.decoder = SharedDecoder(num_input_features, latent_total, dropout_rate)
        self.classifier = nn.Linear(latent_total, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        z = torch.cat([enc(x) for enc in self.encoders], dim=1)
        return self.decoder(z), self.classifier(z)


# ---- ----
DILATIONS = (1,2,3)           
num_input_features = 49    
# ---------------------------------------------

num_classes = len(label_encoder.classes_)
print(num_classes)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes, dilations=DILATIONS).to(device)

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.036046984980646686, Classification Loss: 0.2444749149489947
# Epoch 1, Validation Accuracy: 0.9684
# Epoch [2/100], Reconstruction Loss: 0.03534914921253794, Classification Loss: 0.16528163179034955
# Epoch 2, Validation Accuracy: 0.9760
# Epoch [3/100], Reconstruction Loss: 0.035765603905767614, Classification Loss: 0.14546713344850268
# Epoch 3, Validation Accuracy: 0.9694
# Epoch [4/100], Reconstruction Loss: 0.03654137887477632, Classification Loss: 0.13696414997782502
# Epoch 4, Validation Accuracy: 0.9750
# Epoch [5/100], Reconstruction Loss: 0.03678215431085479, Classification Loss: 0.1244807877802718
# Epoch 5, Validation Accuracy: 0.9363
# Epoch [6/100], Reconstruction Loss: 0.03834872765715411, Classification Loss: 0.12343677786235885
# Epoch 6, Validation Accuracy: 0.9785
# Epoch [7/100], Reconstruction Loss: 0.036731988747771664, Classification Loss: 0.11616113573752224
# Epoch 7, Validation Accuracy: 0.9806
# Epoch [8/100], Reconstruction Loss: 0.03715295512903428, Classification Loss: 0.11107124894285264
# Epoch 8, Validation Accuracy: 0.9843
# Epoch [9/100], Reconstruction Loss: 0.0373931205792883, Classification Loss: 0.10540005029229926
# Epoch 9, Validation Accuracy: 0.9753
# Epoch [10/100], Reconstruction Loss: 0.037652962839875063, Classification Loss: 0.10486702266731249
# Epoch 10, Validation Accuracy: 0.9794
# Epoch [11/100], Reconstruction Loss: 0.03854386132415739, Classification Loss: 0.10932455459343729
# Epoch 11, Validation Accuracy: 0.9788
# Epoch [12/100], Reconstruction Loss: 0.038540101223596135, Classification Loss: 0.10038290840770867
# Epoch 12, Validation Accuracy: 0.9843
# Epoch [13/100], Reconstruction Loss: 0.03843848995657521, Classification Loss: 0.09553700005032473
# Epoch 13, Validation Accuracy: 0.9864
# Epoch [14/100], Reconstruction Loss: 0.0385865910748554, Classification Loss: 0.09767507867050794
# Epoch 14, Validation Accuracy: 0.9843
# Epoch [15/100], Reconstruction Loss: 0.038430480251820096, Classification Loss: 0.09634336227525243
# Epoch 15, Validation Accuracy: 0.9807
# Epoch [16/100], Reconstruction Loss: 0.0387354283831198, Classification Loss: 0.09703858082892401
# Epoch 16, Validation Accuracy: 0.9882
# Epoch [17/100], Reconstruction Loss: 0.0396082184283838, Classification Loss: 0.09096685631632147
# Epoch 17, Validation Accuracy: 0.9732
# Epoch [18/100], Reconstruction Loss: 0.03875204451519713, Classification Loss: 0.09009613591023055
# Epoch 18, Validation Accuracy: 0.9766
# Epoch [19/100], Reconstruction Loss: 0.038954618836542276, Classification Loss: 0.09694351595222624
# Epoch 19, Validation Accuracy: 0.9856
# Epoch [20/100], Reconstruction Loss: 0.03889088335062922, Classification Loss: 0.09337216668061236
# Epoch 20, Validation Accuracy: 0.9873
# Epoch [21/100], Reconstruction Loss: 0.03889897388156581, Classification Loss: 0.09427290369597034
# Epoch 21, Validation Accuracy: 0.9844
# Epoch [22/100], Reconstruction Loss: 0.03859911480305768, Classification Loss: 0.0912395504650187
# Epoch 22, Validation Accuracy: 0.9811
# Epoch [23/100], Reconstruction Loss: 0.03881107264571081, Classification Loss: 0.09005324757211305
# Epoch 23, Validation Accuracy: 0.9740
# Epoch [24/100], Reconstruction Loss: 0.03871689352887473, Classification Loss: 0.08814763625322725
# Epoch 24, Validation Accuracy: 0.9748
# Epoch [25/100], Reconstruction Loss: 0.03890392505529272, Classification Loss: 0.08894212415865224
# Epoch 25, Validation Accuracy: 0.9824
# Epoch [26/100], Reconstruction Loss: 0.038608257486703594, Classification Loss: 0.08999011371587853
# Epoch 26, Validation Accuracy: 0.9745
# Epoch [27/100], Reconstruction Loss: 0.03876378589859014, Classification Loss: 0.08756288358354639
# Epoch 27, Validation Accuracy: 0.9898
# Epoch [28/100], Reconstruction Loss: 0.03905316246590879, Classification Loss: 0.09093592635302142
# Epoch 28, Validation Accuracy: 0.9861
# Epoch [29/100], Reconstruction Loss: 0.03858662589107519, Classification Loss: 0.08560541602301268
# Epoch 29, Validation Accuracy: 0.9887
# Epoch [30/100], Reconstruction Loss: 0.039056366270261544, Classification Loss: 0.08559678888071866
# Epoch 30, Validation Accuracy: 0.9865
# Epoch [31/100], Reconstruction Loss: 0.039695354414932396, Classification Loss: 0.08948363799277272
# Epoch 31, Validation Accuracy: 0.9766
# Epoch [32/100], Reconstruction Loss: 0.03935624894985653, Classification Loss: 0.08565289283849649
# Epoch 32, Validation Accuracy: 0.9898
# Epoch [33/100], Reconstruction Loss: 0.039430377726554264, Classification Loss: 0.08154429589059198
# Epoch 33, Validation Accuracy: 0.9936
# Epoch [34/100], Reconstruction Loss: 0.03947510200303938, Classification Loss: 0.08905577201513742
# Epoch 34, Validation Accuracy: 0.9852
# Epoch [35/100], Reconstruction Loss: 0.03949046695448143, Classification Loss: 0.0808424058146634
# Epoch 35, Validation Accuracy: 0.9856
# Epoch [36/100], Reconstruction Loss: 0.040995605191374816, Classification Loss: 0.08000203006816095
# Epoch 36, Validation Accuracy: 0.9839
# Epoch [37/100], Reconstruction Loss: 0.04798496821452528, Classification Loss: 0.08219749832674841
# Epoch 37, Validation Accuracy: 0.9902
# Epoch [38/100], Reconstruction Loss: 0.04802716940182173, Classification Loss: 0.080018691327278
# Epoch 38, Validation Accuracy: 0.9865
# Epoch [39/100], Reconstruction Loss: 0.048029303647656826, Classification Loss: 0.0802892474968028
# Epoch 39, Validation Accuracy: 0.9930
# Epoch [40/100], Reconstruction Loss: 0.04798649720872518, Classification Loss: 0.08001374154041481
# Epoch 40, Validation Accuracy: 0.9900
# Epoch [41/100], Reconstruction Loss: 0.04797166522398975, Classification Loss: 0.08295575085536304
# Epoch 41, Validation Accuracy: 0.9865
# Epoch [42/100], Reconstruction Loss: 0.0479805401549001, Classification Loss: 0.07618623348991037
# Epoch 42, Validation Accuracy: 0.9910
# Epoch [43/100], Reconstruction Loss: 0.04797436049886872, Classification Loss: 0.08620430293069822
# Epoch 43, Validation Accuracy: 0.9885
# Epoch [44/100], Reconstruction Loss: 0.0479989999219903, Classification Loss: 0.07809264935938383
# Epoch 44, Validation Accuracy: 0.9779
# Epoch [45/100], Reconstruction Loss: 0.04802232288199986, Classification Loss: 0.07591915287492454
# Epoch 45, Validation Accuracy: 0.9625
# Epoch [46/100], Reconstruction Loss: 0.048016107065903965, Classification Loss: 0.09906009304300514
# Epoch 46, Validation Accuracy: 0.9893
# Epoch [47/100], Reconstruction Loss: 0.048050058319209395, Classification Loss: 0.07647275135173841
# Epoch 47, Validation Accuracy: 0.9934
# Epoch [48/100], Reconstruction Loss: 0.04803632314571861, Classification Loss: 0.07989193476258767
# Epoch 48, Validation Accuracy: 0.9908
# Epoch [49/100], Reconstruction Loss: 0.048041056299524994, Classification Loss: 0.07665674464294392
# Epoch 49, Validation Accuracy: 0.9878
# Epoch [50/100], Reconstruction Loss: 0.04807319860352491, Classification Loss: 0.07851775079390673
# Epoch 50, Validation Accuracy: 0.9948
# Epoch [51/100], Reconstruction Loss: 0.04804728124445045, Classification Loss: 0.07978727002827504
# Epoch 51, Validation Accuracy: 0.9709
# Epoch [52/100], Reconstruction Loss: 0.04802896613115695, Classification Loss: 0.07186249330346253
# Epoch 52, Validation Accuracy: 0.9950
# Epoch [53/100], Reconstruction Loss: 0.048103952807713984, Classification Loss: 0.07414962090092556
# Epoch 53, Validation Accuracy: 0.9875
# Epoch [54/100], Reconstruction Loss: 0.04805577540509419, Classification Loss: 0.07735895968984027
# Epoch 54, Validation Accuracy: 0.9862
# Epoch [55/100], Reconstruction Loss: 0.048064070997854744, Classification Loss: 0.08151364021209642
# Epoch 55, Validation Accuracy: 0.9898
# Epoch [56/100], Reconstruction Loss: 0.04804055486158726, Classification Loss: 0.0755776439372551
# Epoch 56, Validation Accuracy: 0.9944
# Epoch [57/100], Reconstruction Loss: 0.04804075136997357, Classification Loss: 0.07057411669108664
# Epoch 57, Validation Accuracy: 0.9952
# Epoch [58/100], Reconstruction Loss: 0.04805223652552789, Classification Loss: 0.10009463169376553
# Epoch 58, Validation Accuracy: 0.9914
# Epoch [59/100], Reconstruction Loss: 0.048045881533366266, Classification Loss: 0.07203805941905188
# Epoch 59, Validation Accuracy: 0.9832
# Epoch [60/100], Reconstruction Loss: 0.04805467061255453, Classification Loss: 0.08294134164138123
# Epoch 60, Validation Accuracy: 0.9940
# Epoch [61/100], Reconstruction Loss: 0.04804713382877259, Classification Loss: 0.09149587787385528
# Epoch 61, Validation Accuracy: 0.9894
# Epoch [62/100], Reconstruction Loss: 0.0480304429214705, Classification Loss: 0.08106889456040009
# Epoch 62, Validation Accuracy: 0.9905
# Epoch [63/100], Reconstruction Loss: 0.04804210126538629, Classification Loss: 0.08550556545199253
# Epoch 63, Validation Accuracy: 0.9892
# Epoch [64/100], Reconstruction Loss: 0.048035742362184324, Classification Loss: 0.09051329772356209
# Epoch 64, Validation Accuracy: 0.9880
# Epoch [65/100], Reconstruction Loss: 0.04804384613092564, Classification Loss: 0.08611113049339968
# Epoch 65, Validation Accuracy: 0.9739
# Epoch [66/100], Reconstruction Loss: 0.04805478125188929, Classification Loss: 0.08998685246947456
# Epoch 66, Validation Accuracy: 0.9885
# Epoch [67/100], Reconstruction Loss: 0.04805044995774917, Classification Loss: 0.09228459399262978
# Epoch 67, Validation Accuracy: 0.9917
# Epoch [68/100], Reconstruction Loss: 0.0480382495686609, Classification Loss: 0.09871602567371865
# Epoch 68, Validation Accuracy: 0.9936
# Epoch [69/100], Reconstruction Loss: 0.048004254418232875, Classification Loss: 0.13698153061082693
# Epoch 69, Validation Accuracy: 0.9930
# Epoch [70/100], Reconstruction Loss: 0.04800501549574486, Classification Loss: 0.07815558262997113
# Epoch 70, Validation Accuracy: 0.9876
# Epoch [71/100], Reconstruction Loss: 0.048001335762405416, Classification Loss: 0.0872749808814519
# Epoch 71, Validation Accuracy: 0.9796
# Epoch [72/100], Reconstruction Loss: 0.04803082906603293, Classification Loss: 0.08941608178543961
# Epoch 72, Validation Accuracy: 0.9939
# Epoch [73/100], Reconstruction Loss: 0.048031696615688395, Classification Loss: 0.08389499663988415
# Epoch 73, Validation Accuracy: 0.9911
# Epoch [74/100], Reconstruction Loss: 0.04802449066248774, Classification Loss: 0.08342400108520112
# Epoch 74, Validation Accuracy: 0.9791
# Epoch [75/100], Reconstruction Loss: 0.048028771810613755, Classification Loss: 0.07937458742503091
# Epoch 75, Validation Accuracy: 0.9896
# Epoch [76/100], Reconstruction Loss: 0.04802394893953474, Classification Loss: 0.08501947127170723
# Epoch 76, Validation Accuracy: 0.9942
# Epoch [77/100], Reconstruction Loss: 0.048020681506855435, Classification Loss: 0.07791316064860655
# Epoch 77, Validation Accuracy: 0.9941
# Epoch [78/100], Reconstruction Loss: 0.0480327098578245, Classification Loss: 0.0829646064485952
# Epoch 78, Validation Accuracy: 0.9927
# Epoch [79/100], Reconstruction Loss: 0.048035959333943876, Classification Loss: 0.08911917131015201
# Epoch 79, Validation Accuracy: 0.9927
# Epoch [80/100], Reconstruction Loss: 0.04802694117458412, Classification Loss: 0.08161098402586878
# Epoch 80, Validation Accuracy: 0.9802
# Epoch [81/100], Reconstruction Loss: 0.048052007505467925, Classification Loss: 0.08045017305721096
# Epoch 81, Validation Accuracy: 0.9879
# Epoch [82/100], Reconstruction Loss: 0.048031205236955095, Classification Loss: 0.08207466988149069
# Epoch 82, Validation Accuracy: 0.9942
# Epoch [83/100], Reconstruction Loss: 0.048031123157637745, Classification Loss: 0.1229371332423352
# Epoch 83, Validation Accuracy: 0.9872
# Epoch [84/100], Reconstruction Loss: 0.04805293377325846, Classification Loss: 0.08419831172544655
# Epoch 84, Validation Accuracy: 0.9663
# Epoch [85/100], Reconstruction Loss: 0.04799697917701547, Classification Loss: 0.07178650165956507
# Epoch 85, Validation Accuracy: 0.9777
# Epoch [86/100], Reconstruction Loss: 0.04799964247093521, Classification Loss: 0.08988696540140487
# Epoch 86, Validation Accuracy: 0.9961
# Epoch [87/100], Reconstruction Loss: 0.04801353143463389, Classification Loss: 0.09093943404946013
# Epoch 87, Validation Accuracy: 0.9868
# Epoch [88/100], Reconstruction Loss: 0.04800571924039471, Classification Loss: 0.09024176510884839
# Epoch 88, Validation Accuracy: 0.9947
# Epoch [89/100], Reconstruction Loss: 0.048000532464395174, Classification Loss: 0.0897850139956962
# Epoch 89, Validation Accuracy: 0.9938
# Epoch [90/100], Reconstruction Loss: 0.048005515777483326, Classification Loss: 0.07982980506411717
# Epoch 90, Validation Accuracy: 0.9697
# Epoch [91/100], Reconstruction Loss: 0.04799647585937391, Classification Loss: 0.08107175573409141
# Epoch 91, Validation Accuracy: 0.9917
# Epoch [92/100], Reconstruction Loss: 0.048018608528209265, Classification Loss: 0.09365849981123703
# Epoch 92, Validation Accuracy: 0.9970
# Epoch [93/100], Reconstruction Loss: 0.0479991122428233, Classification Loss: 0.08989687678884097
# Epoch 93, Validation Accuracy: 0.9698
# Epoch [94/100], Reconstruction Loss: 0.04800896741572222, Classification Loss: 0.09507649180680125
# Epoch 94, Validation Accuracy: 0.9757
# Epoch [95/100], Reconstruction Loss: 0.04801688198964685, Classification Loss: 0.08073208288832404
# Epoch 95, Validation Accuracy: 0.9666
# Epoch [96/100], Reconstruction Loss: 0.04802383777977492, Classification Loss: 0.07780636233639575
# Epoch 96, Validation Accuracy: 0.9967
# Epoch [97/100], Reconstruction Loss: 0.04803863167708602, Classification Loss: 0.08836177640249239
# Epoch 97, Validation Accuracy: 0.9776
# Epoch [98/100], Reconstruction Loss: 0.04803058736839688, Classification Loss: 0.0768278387064312
# Epoch 98, Validation Accuracy: 0.9946
# Epoch [99/100], Reconstruction Loss: 0.04805122265682385, Classification Loss: 0.07428533961904339
# Epoch 99, Validation Accuracy: 0.9941
# Epoch [100/100], Reconstruction Loss: 0.04856111715516737, Classification Loss: 0.09556735752924302
# Epoch 100, Validation Accuracy: 0.9657

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9658173244014965
# Precision: 0.967419710053609
# Recall: 0.9658173244014965
# F1 Score: 0.9658463447050182
# Confusion Matrix:
#  [[72386  4529     0     0     0]
#  [  475 65696     0     0     0]
#  [    0     2    16     1     0]
#  [    0     1     3  3627     0]
#  [    5     0     0     0     0]]
