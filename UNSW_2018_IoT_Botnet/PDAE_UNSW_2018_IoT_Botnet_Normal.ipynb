# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the Model

# %%
import torch
import torch.nn as nn

KERNEL = 3
HIDDEN = 64   # linear layer width before the conv layer
LATENT = 32   # latent size per branch


class ConvEncoder(nn.Module):
    def __init__(self, n_in, dilation, dropout, latent=LATENT):
        super().__init__()
        conv_len = HIDDEN - dilation * (KERNEL - 1)
        self.net = nn.Sequential(
            nn.Linear(n_in, HIDDEN),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Conv1d(1, 1, kernel_size=KERNEL, stride=1, dilation=dilation),
            nn.Flatten(),
            nn.Linear(conv_len, latent),
        )

    def forward(self, x):
        return self.net(x.unsqueeze(1))


class ConvDecoder(nn.Module):
    def __init__(self, n_out, dilation, dropout, latent=LATENT):
        super().__init__()
        mid = n_out - dilation * (KERNEL - 1)
        self.net = nn.Sequential(
            nn.Linear(latent, mid),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Unflatten(dim=1, unflattened_size=(1, mid)),
            nn.ConvTranspose1d(1, 1, kernel_size=KERNEL, stride=1, dilation=dilation),
            nn.Flatten(),
            nn.Linear(n_out, n_out),
        )

    def forward(self, z):
        return self.net(z)


class SharedDecoder(nn.Module):
    def __init__(self, n_out, in_dim, dropout):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, n_out),
        )

    def forward(self, z):
        return self.net(z)


class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dilations=(1,), dropout_rate=0.4):
        super().__init__()
        self.num_input_features = num_input_features
        self.dilations = tuple(dilations)
        self.encoders = nn.ModuleList(
            [ConvEncoder(num_input_features, d, dropout_rate) for d in self.dilations]
        )
        latent_total = LATENT * len(self.dilations)
        if len(self.dilations) == 1:
            self.decoder = ConvDecoder(num_input_features, self.dilations[0], dropout_rate)
        else:
            self.decoder = SharedDecoder(num_input_features, latent_total, dropout_rate)
        self.classifier = nn.Linear(latent_total, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        z = torch.cat([enc(x) for enc in self.encoders], dim=1)
        return self.decoder(z), self.classifier(z)


# ---- ----
DILATIONS = (1,)           
num_input_features = 49    
# ---------------------------------------------

num_classes = len(label_encoder.classes_)
print(num_classes)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes, dilations=DILATIONS).to(device)

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.0483155725072993, Classification Loss: 0.27545215266681305
# Epoch 1, Validation Accuracy: 0.9669
# Epoch [2/100], Reconstruction Loss: 0.04803329036896148, Classification Loss: 0.20596346013797093
# Epoch 2, Validation Accuracy: 0.9567
# Epoch [3/100], Reconstruction Loss: 0.04802481861475561, Classification Loss: 0.192491166702217
# Epoch 3, Validation Accuracy: 0.9506
# Epoch [4/100], Reconstruction Loss: 0.047985930509701735, Classification Loss: 0.18825169473611386
# Epoch 4, Validation Accuracy: 0.9590
# Epoch [5/100], Reconstruction Loss: 0.04795311811863553, Classification Loss: 0.1704120257902397
# Epoch 5, Validation Accuracy: 0.9515
# Epoch [6/100], Reconstruction Loss: 0.047942930745587205, Classification Loss: 0.16200210408230847
# Epoch 6, Validation Accuracy: 0.9608
# Epoch [7/100], Reconstruction Loss: 0.04797805299209914, Classification Loss: 0.15585004237266145
# Epoch 7, Validation Accuracy: 0.9415
# Epoch [8/100], Reconstruction Loss: 0.047965631824729224, Classification Loss: 0.1609045129855855
# Epoch 8, Validation Accuracy: 0.9526
# Epoch [9/100], Reconstruction Loss: 0.047980184593026866, Classification Loss: 0.15455579377484996
# Epoch 9, Validation Accuracy: 0.9758
# Epoch [10/100], Reconstruction Loss: 0.04797050811058994, Classification Loss: 0.15087574295702846
# Epoch 10, Validation Accuracy: 0.9407
# Epoch [11/100], Reconstruction Loss: 0.047956079976241385, Classification Loss: 0.15318394605414776
# Epoch 11, Validation Accuracy: 0.9611
# Epoch [12/100], Reconstruction Loss: 0.04798393219607586, Classification Loss: 0.14111489240095823
# Epoch 12, Validation Accuracy: 0.9594
# Epoch [13/100], Reconstruction Loss: 0.047977119069565415, Classification Loss: 0.13543818115765374
# Epoch 13, Validation Accuracy: 0.9760
# Epoch [14/100], Reconstruction Loss: 0.0479689322423928, Classification Loss: 0.14242778480692514
# Epoch 14, Validation Accuracy: 0.9795
# Epoch [15/100], Reconstruction Loss: 0.04800176784896559, Classification Loss: 0.13914327863154347
# Epoch 15, Validation Accuracy: 0.9569
# Epoch [16/100], Reconstruction Loss: 0.04801060890404962, Classification Loss: 0.14055279099078788
# Epoch 16, Validation Accuracy: 0.9500
# Epoch [17/100], Reconstruction Loss: 0.048013202018569005, Classification Loss: 0.13906618950124666
# Epoch 17, Validation Accuracy: 0.9584
# Epoch [18/100], Reconstruction Loss: 0.04801031959645622, Classification Loss: 0.13803857251777563
# Epoch 18, Validation Accuracy: 0.9736
# Epoch [19/100], Reconstruction Loss: 0.04800349482076427, Classification Loss: 0.13478838887555342
# Epoch 19, Validation Accuracy: 0.9633
# Epoch [20/100], Reconstruction Loss: 0.04799667182350717, Classification Loss: 0.13237595217426185
# Epoch 20, Validation Accuracy: 0.9704
# Epoch [21/100], Reconstruction Loss: 0.04796865694782626, Classification Loss: 0.13659868471100786
# Epoch 21, Validation Accuracy: 0.9607
# Epoch [22/100], Reconstruction Loss: 0.04796033784983238, Classification Loss: 0.1350505692305008
# Epoch 22, Validation Accuracy: 0.9602
# Epoch [23/100], Reconstruction Loss: 0.047972877538729274, Classification Loss: 0.13295051427946622
# Epoch 23, Validation Accuracy: 0.9626
# Epoch [24/100], Reconstruction Loss: 0.04798548491970885, Classification Loss: 0.13427056900226528
# Epoch 24, Validation Accuracy: 0.9580
# Epoch [25/100], Reconstruction Loss: 0.047975965241721104, Classification Loss: 0.1300640994955576
# Epoch 25, Validation Accuracy: 0.9564
# Epoch [26/100], Reconstruction Loss: 0.047977170320873536, Classification Loss: 0.1275280827490811
# Epoch 26, Validation Accuracy: 0.9720
# Epoch [27/100], Reconstruction Loss: 0.047994496623848325, Classification Loss: 0.13015819088225394
# Epoch 27, Validation Accuracy: 0.9641
# Epoch [28/100], Reconstruction Loss: 0.04800601601643971, Classification Loss: 0.13554230178751703
# Epoch 28, Validation Accuracy: 0.9636
# Epoch [29/100], Reconstruction Loss: 0.04799937919921646, Classification Loss: 0.13253178078056288
# Epoch 29, Validation Accuracy: 0.9626
# Epoch [30/100], Reconstruction Loss: 0.04799442179419825, Classification Loss: 0.14125776321802255
# Epoch 30, Validation Accuracy: 0.9642
# Epoch [31/100], Reconstruction Loss: 0.04797750907805375, Classification Loss: 0.14837287707306548
# Epoch 31, Validation Accuracy: 0.9649
# Epoch [32/100], Reconstruction Loss: 0.04803282909689904, Classification Loss: 0.13724423808737915
# Epoch 32, Validation Accuracy: 0.9632
# Epoch [33/100], Reconstruction Loss: 0.048000036966668116, Classification Loss: 0.13360924024022774
# Epoch 33, Validation Accuracy: 0.9660
# Epoch [34/100], Reconstruction Loss: 0.0480167312586285, Classification Loss: 0.12613351191247138
# Epoch 34, Validation Accuracy: 0.9645
# Epoch [35/100], Reconstruction Loss: 0.047982318849692875, Classification Loss: 0.14028502495975376
# Epoch 35, Validation Accuracy: 0.9650
# Epoch [36/100], Reconstruction Loss: 0.04798849320507861, Classification Loss: 0.14288274497974315
# Epoch 36, Validation Accuracy: 0.9648
# Epoch [37/100], Reconstruction Loss: 0.04799139450979382, Classification Loss: 0.1313404903876706
# Epoch 37, Validation Accuracy: 0.9616
# Epoch [38/100], Reconstruction Loss: 0.048017458989945486, Classification Loss: 0.12917830292197754
# Epoch 38, Validation Accuracy: 0.9673
# Epoch [39/100], Reconstruction Loss: 0.047996546970773775, Classification Loss: 0.1365038467027428
# Epoch 39, Validation Accuracy: 0.9669
# Epoch [40/100], Reconstruction Loss: 0.048021364125822114, Classification Loss: 0.13806733842205343
# Epoch 40, Validation Accuracy: 0.9644
# Epoch [41/100], Reconstruction Loss: 0.04801428161083846, Classification Loss: 0.1280114373916779
# Epoch 41, Validation Accuracy: 0.9671
# Epoch [42/100], Reconstruction Loss: 0.047994367800504596, Classification Loss: 0.13806555779827623
# Epoch 42, Validation Accuracy: 0.9677
# Epoch [43/100], Reconstruction Loss: 0.04800114295223214, Classification Loss: 0.1459912000944791
# Epoch 43, Validation Accuracy: 0.9658
# Epoch [44/100], Reconstruction Loss: 0.047983299241689495, Classification Loss: 0.12949797674254837
# Epoch 44, Validation Accuracy: 0.9666
# Epoch [45/100], Reconstruction Loss: 0.04797312752255036, Classification Loss: 0.15673535418796752
# Epoch 45, Validation Accuracy: 0.9659
# Epoch [46/100], Reconstruction Loss: 0.04797522259407966, Classification Loss: 0.14654930031785682
# Epoch 46, Validation Accuracy: 0.9661
# Epoch [47/100], Reconstruction Loss: 0.04798535556510916, Classification Loss: 0.12417599794700328
# Epoch 47, Validation Accuracy: 0.9654
# Epoch [48/100], Reconstruction Loss: 0.04800424763646076, Classification Loss: 0.14793072201560428
# Epoch 48, Validation Accuracy: 0.9689
# Epoch [49/100], Reconstruction Loss: 0.04799782981529349, Classification Loss: 0.13253450556099738
# Epoch 49, Validation Accuracy: 0.9731
# Epoch [50/100], Reconstruction Loss: 0.04798273924374792, Classification Loss: 0.12391611219680679
# Epoch 50, Validation Accuracy: 0.9680
# Epoch [51/100], Reconstruction Loss: 0.047961145293372094, Classification Loss: 0.12245479612322184
# Epoch 51, Validation Accuracy: 0.9719
# Epoch [52/100], Reconstruction Loss: 0.04797303845567366, Classification Loss: 0.12365094607127043
# Epoch 52, Validation Accuracy: 0.9758
# Epoch [53/100], Reconstruction Loss: 0.047995836734620094, Classification Loss: 0.13185317142576689
# Epoch 53, Validation Accuracy: 0.9709
# Epoch [54/100], Reconstruction Loss: 0.04802077138767476, Classification Loss: 0.13483378664633877
# Epoch 54, Validation Accuracy: 0.9699
# Epoch [55/100], Reconstruction Loss: 0.04800641297403767, Classification Loss: 0.12832848571122032
# Epoch 55, Validation Accuracy: 0.9718
# Epoch [56/100], Reconstruction Loss: 0.04803465406024139, Classification Loss: 0.1356855438875154
# Epoch 56, Validation Accuracy: 0.9528
# Epoch [57/100], Reconstruction Loss: 0.04803667260708374, Classification Loss: 0.13745734527076742
# Epoch 57, Validation Accuracy: 0.9681
# Epoch [58/100], Reconstruction Loss: 0.04801038376416192, Classification Loss: 0.14100639710912508
# Epoch 58, Validation Accuracy: 0.9688
# Epoch [59/100], Reconstruction Loss: 0.04801505009073351, Classification Loss: 0.13416994332824228
# Epoch 59, Validation Accuracy: 0.9731
# Epoch [60/100], Reconstruction Loss: 0.0480219381887789, Classification Loss: 0.12717726198177357
# Epoch 60, Validation Accuracy: 0.9735
# Epoch [61/100], Reconstruction Loss: 0.04800395555019829, Classification Loss: 0.12551216880607713
# Epoch 61, Validation Accuracy: 0.9753
# Epoch [62/100], Reconstruction Loss: 0.04804326676028311, Classification Loss: 0.1321927769577231
# Epoch 62, Validation Accuracy: 0.9620
# Epoch [63/100], Reconstruction Loss: 0.048037668484027414, Classification Loss: 0.15092735140630306
# Epoch 63, Validation Accuracy: 0.9724
# Epoch [64/100], Reconstruction Loss: 0.04805244632885196, Classification Loss: 0.13402507497047264
# Epoch 64, Validation Accuracy: 0.9701
# Epoch [65/100], Reconstruction Loss: 0.048030847944844544, Classification Loss: 0.12710432377460434
# Epoch 65, Validation Accuracy: 0.9702
# Epoch [66/100], Reconstruction Loss: 0.048017007754342575, Classification Loss: 0.1359955775798578
# Epoch 66, Validation Accuracy: 0.9751
# Epoch [67/100], Reconstruction Loss: 0.0480047974067773, Classification Loss: 0.12277320879337564
# Epoch 67, Validation Accuracy: 0.9757
# Epoch [68/100], Reconstruction Loss: 0.04802370376409461, Classification Loss: 0.11690478090715106
# Epoch 68, Validation Accuracy: 0.9787
# Epoch [69/100], Reconstruction Loss: 0.04802620276886721, Classification Loss: 0.11626799885086907
# Epoch 69, Validation Accuracy: 0.9765
# Epoch [70/100], Reconstruction Loss: 0.04801094452026695, Classification Loss: 0.11710631661056153
# Epoch 70, Validation Accuracy: 0.9799
# Epoch [71/100], Reconstruction Loss: 0.048017169147846844, Classification Loss: 0.11437132760040546
# Epoch 71, Validation Accuracy: 0.9823
# Epoch [72/100], Reconstruction Loss: 0.04799660198311418, Classification Loss: 0.13176207519562158
# Epoch 72, Validation Accuracy: 0.9761
# Epoch [73/100], Reconstruction Loss: 0.04800172095114035, Classification Loss: 0.11507377852142174
# Epoch 73, Validation Accuracy: 0.9648
# Epoch [74/100], Reconstruction Loss: 0.04799602107502447, Classification Loss: 0.12755143802594338
# Epoch 74, Validation Accuracy: 0.9712
# Epoch [75/100], Reconstruction Loss: 0.04802032347986788, Classification Loss: 0.10988424295751233
# Epoch 75, Validation Accuracy: 0.9865
# Epoch [76/100], Reconstruction Loss: 0.04801143468160635, Classification Loss: 0.11312173368603691
# Epoch 76, Validation Accuracy: 0.9816
# Epoch [77/100], Reconstruction Loss: 0.04802253684980749, Classification Loss: 0.11827137066037284
# Epoch 77, Validation Accuracy: 0.9706
# Epoch [78/100], Reconstruction Loss: 0.0480226871562543, Classification Loss: 0.13203778349500522
# Epoch 78, Validation Accuracy: 0.9743
# Epoch [79/100], Reconstruction Loss: 0.048040057597880895, Classification Loss: 0.13687062570775127
# Epoch 79, Validation Accuracy: 0.9869
# Epoch [80/100], Reconstruction Loss: 0.04802200290236228, Classification Loss: 0.11160229577110635
# Epoch 80, Validation Accuracy: 0.9901
# Epoch [81/100], Reconstruction Loss: 0.04802929125709977, Classification Loss: 0.13423694695368668
# Epoch 81, Validation Accuracy: 0.9905
# Epoch [82/100], Reconstruction Loss: 0.04800977688518301, Classification Loss: 0.13170400121375034
# Epoch 82, Validation Accuracy: 0.9801
# Epoch [83/100], Reconstruction Loss: 0.04798939899974809, Classification Loss: 0.10794526660911818
# Epoch 83, Validation Accuracy: 0.9906
# Epoch [84/100], Reconstruction Loss: 0.048028265409954654, Classification Loss: 0.11559174227182903
# Epoch 84, Validation Accuracy: 0.9747
# Epoch [85/100], Reconstruction Loss: 0.04806791901802892, Classification Loss: 0.11462279723374749
# Epoch 85, Validation Accuracy: 0.9850
# Epoch [86/100], Reconstruction Loss: 0.04802913068728593, Classification Loss: 0.11045778816819585
# Epoch 86, Validation Accuracy: 0.9888
# Epoch [87/100], Reconstruction Loss: 0.04801428565509896, Classification Loss: 0.13040166791609153
# Epoch 87, Validation Accuracy: 0.9777
# Epoch [88/100], Reconstruction Loss: 0.048002493250554584, Classification Loss: 0.10955291604283379
# Epoch 88, Validation Accuracy: 0.9751
# Epoch [89/100], Reconstruction Loss: 0.04802647087171182, Classification Loss: 0.11823282507116221
# Epoch 89, Validation Accuracy: 0.9805
# Epoch [90/100], Reconstruction Loss: 0.04801708756133574, Classification Loss: 0.10463574701237263
# Epoch 90, Validation Accuracy: 0.9914
# Epoch [91/100], Reconstruction Loss: 0.04801764818530371, Classification Loss: 0.10733541819577146
# Epoch 91, Validation Accuracy: 0.9755
# Epoch [92/100], Reconstruction Loss: 0.0480158711806739, Classification Loss: 0.12507494712743417
# Epoch 92, Validation Accuracy: 0.9773
# Epoch [93/100], Reconstruction Loss: 0.04801944458917019, Classification Loss: 0.11948402258051014
# Epoch 93, Validation Accuracy: 0.9853
# Epoch [94/100], Reconstruction Loss: 0.04801411094066275, Classification Loss: 0.10815510787913254
# Epoch 94, Validation Accuracy: 0.9753
# Epoch [95/100], Reconstruction Loss: 0.048007342082233444, Classification Loss: 0.1216684900629894
# Epoch 95, Validation Accuracy: 0.9958
# Epoch [96/100], Reconstruction Loss: 0.0480239250411395, Classification Loss: 0.1581050802195107
# Epoch 96, Validation Accuracy: 0.9882
# Epoch [97/100], Reconstruction Loss: 0.0480117732730737, Classification Loss: 0.11178701717022285
# Epoch 97, Validation Accuracy: 0.9838
# Epoch [98/100], Reconstruction Loss: 0.048012535583684395, Classification Loss: 0.11392668773647469
# Epoch 98, Validation Accuracy: 0.9773
# Epoch [99/100], Reconstruction Loss: 0.048002401498154615, Classification Loss: 0.11235381125158796
# Epoch 99, Validation Accuracy: 0.9772
# Epoch [100/100], Reconstruction Loss: 0.048014957687396054, Classification Loss: 0.16326342394880367
# Epoch 100, Validation Accuracy: 0.9701

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9704445247067963
# Precision: 0.9721490804464016
# Recall: 0.9704445247067963
# F1 Score: 0.9704695130294079
# Confusion Matrix:
#  [[72665  4250     0     0     0]
#  [   67 66104     0     0     0]
#  [    0     2    17     0     0]
#  [    4     9     0  3618     0]
#  [    2     3     0     0     0]]
