# %% [markdown]
# Step 1: Data Preprocessing

# %%
import pandas as pd
import numpy as np
import torch
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset

# Set a fixed random seed for reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Convert hex to numeric if applicable
def convert_hex_to_numeric(value):
    if isinstance(value, str) and value.startswith('0x'):
        return int(value, 16)
    else:
        return value

# Create a 7x7 matrix from a row of data
def create_7x7_matrix(data_row):
    numeric_row = pd.to_numeric(data_row.apply(convert_hex_to_numeric), errors='coerce').fillna(0)
    num_elements_required = 49
    if len(numeric_row) < num_elements_required:
        numeric_row = np.pad(numeric_row, (0, num_elements_required - len(numeric_row)), 'constant')
    matrix = np.array(numeric_row).reshape(7, 7)
    return matrix

# Process the dataset to create 7x7 matrices
def process_dataset(dataset):
    matrices = []
    for _, row in dataset.iterrows():
        matrix = create_7x7_matrix(row)
        matrices.append(matrix)
    return matrices

# Load dataset
df = pd.read_csv('UNSW_2018_IoT_Botnet.csv')

# Drop irrelevant columns
irrelevant_columns = ['pkSeqID', 'saddr', 'sport', 'daddr', 'dport', 'ltime', 'seq', 'attack', 'subcategory']
df = df.drop(columns=irrelevant_columns)

# Identify non-numeric columns (flgs, proto, state)
non_numeric_columns = ['flgs', 'proto', 'state']

# Encode non-numeric columns
le = LabelEncoder()
for col in non_numeric_columns:
    df[col] = le.fit_transform(df[col])

# Encode target labels (category)
label_encoder = LabelEncoder()
df['category'] = label_encoder.fit_transform(df['category'])

# Separate features and target
df_features = df.drop(columns=['category'])
df_target = df['category']

# Ensure all features are numeric
df_features = df_features.apply(pd.to_numeric, errors='coerce').fillna(0)

# Specify the columns to scale
columns_to_scale = df_features.columns  # Scale all feature columns
scaler = MinMaxScaler()
df_features_scaled = scaler.fit_transform(df_features)

# Convert the scaled features back to a DataFrame to apply the 7x7 matrix transformation
df_features_scaled = pd.DataFrame(df_features_scaled)

# Process each row to create 7x7 matrices
matrices = process_dataset(df_features_scaled)

# Convert to a 3D numpy array
X = np.array(matrices)

# Encode the labels
y = label_encoder.fit_transform(df_target)

# Split data
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=SEED)
# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# %% [markdown]
# Step 2: Building the Model

# %%
import torch
import torch.nn as nn

class DeepAutoencoder(nn.Module):
    def __init__(self, num_input_features, num_classes, dropout_rate=0.4):
        super(DeepAutoencoder, self).__init__()
        self.num_input_features = num_input_features

        # Adjust input size for Conv1d with dilation=2
        conv1d_output_size_dilated2 = (num_input_features - 2 * (3 - 1) - 1) + 1  # Adjusted for dilation=2

        # Dilated Encoder with dilation factor of 2
        self.encoder_dilated2 = nn.Sequential(
            nn.Linear(num_input_features, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Conv1d(in_channels=1, out_channels=1, kernel_size=3, stride=1, dilation=2),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(60, 32)  # Adjusted for conv1d_output_size_dilated2
        )

        # Dilated Decoder with adjusted input and output sizes for dilation=2
        self.decoder_dilated2 = nn.Sequential(
            nn.Linear(32, conv1d_output_size_dilated2),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Unflatten(dim=1, unflattened_size=(1, conv1d_output_size_dilated2)),  # Ensure correct input shape for ConvTranspose1d
            nn.ConvTranspose1d(1, 1, kernel_size=3, stride=1, dilation=2),  # Adjusted dilation
            nn.Flatten(),
            nn.Linear(49, num_input_features)
        )

        # Classifier
        self.classifier = nn.Linear(32, num_classes)

    def forward(self, x):
        x = x.view(-1, self.num_input_features)
        encoded_dilated2 = self.encoder_dilated2(x.unsqueeze(1))
        decoded = self.decoder_dilated2(encoded_dilated2)
        classification = self.classifier(encoded_dilated2)
        return decoded, classification

# Example usage
num_classes = len(label_encoder.classes_)  # Update this based on your dataset
num_input_features = 49  # Update this based on your dataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DeepAutoencoder(num_input_features, num_classes).to(device)

# %% [markdown]
# Step 3: Training the Model

# %%
import torch.optim as optim  # Import the optim module

LEARNING_RATE = 0.01  # Adjusted learning rate
BATCH_SIZE = 64        # Adjusted batch size

criterion_reconstruction = nn.L1Loss()
criterion_classification = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

train_data = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
val_data = TensorDataset(X_val_tensor, y_val_tensor)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)


num_epochs = 100



for epoch in range(num_epochs):
    model.train()
    running_loss_reconstruction = 0.0
    running_loss_classification = 0.0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        decoded, classification = model(inputs.view(-1, num_input_features))
        loss_reconstruction = criterion_reconstruction(decoded, inputs.view(-1, num_input_features))
        loss_classification = criterion_classification(classification, labels)
        loss = loss_reconstruction + loss_classification
        loss.backward()
        optimizer.step()

        running_loss_reconstruction += loss_reconstruction.item()
        running_loss_classification += loss_classification.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Reconstruction Loss: {running_loss_reconstruction / len(train_loader)}, Classification Loss: {running_loss_classification / len(train_loader)}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            decoded, outputs = model(inputs.view(-1, num_input_features)) # فرض بر این است که مدل دو خروجی دارد
            _, predicted = torch.max(outputs, 1) # 'outputs' به جای 'outputs.data' استفاده شده است
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    validation_accuracy = correct / total
    print(f'Epoch {epoch+1}, Validation Accuracy: {validation_accuracy:.4f}')
# Out:
# Epoch [1/100], Reconstruction Loss: 0.048592688151051576, Classification Loss: 0.25514263295580575
# Epoch 1, Validation Accuracy: 0.9555
# Epoch [2/100], Reconstruction Loss: 0.0482700477036206, Classification Loss: 0.17536600584253345
# Epoch 2, Validation Accuracy: 0.9740
# Epoch [3/100], Reconstruction Loss: 0.04825784346631125, Classification Loss: 0.14971567193653557
# Epoch 3, Validation Accuracy: 0.9783
# Epoch [4/100], Reconstruction Loss: 0.048275524865971836, Classification Loss: 0.13682544701719834
# Epoch 4, Validation Accuracy: 0.9705
# Epoch [5/100], Reconstruction Loss: 0.0482667686028057, Classification Loss: 0.12670618447938561
# Epoch 5, Validation Accuracy: 0.9736
# Epoch [6/100], Reconstruction Loss: 0.04830228466866044, Classification Loss: 0.1193273964374965
# Epoch 6, Validation Accuracy: 0.9668
# Epoch [7/100], Reconstruction Loss: 0.048244085956783485, Classification Loss: 0.1182809272006063
# Epoch 7, Validation Accuracy: 0.9665
# Epoch [8/100], Reconstruction Loss: 0.04827553610736971, Classification Loss: 0.1132556115179498
# Epoch 8, Validation Accuracy: 0.9677
# Epoch [9/100], Reconstruction Loss: 0.048285657084794875, Classification Loss: 0.10511536740940668
# Epoch 9, Validation Accuracy: 0.9821
# Epoch [10/100], Reconstruction Loss: 0.04827087574646143, Classification Loss: 0.1079373907652968
# Epoch 10, Validation Accuracy: 0.9792
# Epoch [11/100], Reconstruction Loss: 0.048264436875427336, Classification Loss: 0.10663476921316412
# Epoch 11, Validation Accuracy: 0.9818
# Epoch [12/100], Reconstruction Loss: 0.04825615589301814, Classification Loss: 0.10741360818617655
# Epoch 12, Validation Accuracy: 0.9802
# Epoch [13/100], Reconstruction Loss: 0.04826595778868787, Classification Loss: 0.10388118692020233
# Epoch 13, Validation Accuracy: 0.9773
# Epoch [14/100], Reconstruction Loss: 0.04826380152361981, Classification Loss: 0.10271543781375284
# Epoch 14, Validation Accuracy: 0.9803
# Epoch [15/100], Reconstruction Loss: 0.04828317720415391, Classification Loss: 0.10144542956571506
# Epoch 15, Validation Accuracy: 0.9800
# Epoch [16/100], Reconstruction Loss: 0.04827178407827077, Classification Loss: 0.10192757199145663
# Epoch 16, Validation Accuracy: 0.9798
# Epoch [17/100], Reconstruction Loss: 0.04827285911072859, Classification Loss: 0.10140539979863263
# Epoch 17, Validation Accuracy: 0.9797
# Epoch [18/100], Reconstruction Loss: 0.048271452292945084, Classification Loss: 0.09963461678859097
# Epoch 18, Validation Accuracy: 0.9851
# Epoch [19/100], Reconstruction Loss: 0.04828833998969551, Classification Loss: 0.09639243599763085
# Epoch 19, Validation Accuracy: 0.9818
# Epoch [20/100], Reconstruction Loss: 0.04826176024703703, Classification Loss: 0.09730439217907917
# Epoch 20, Validation Accuracy: 0.9688
# Epoch [21/100], Reconstruction Loss: 0.048281737240547185, Classification Loss: 0.095907251615465
# Epoch 21, Validation Accuracy: 0.9763
# Epoch [22/100], Reconstruction Loss: 0.048284824209203554, Classification Loss: 0.0955971776722416
# Epoch 22, Validation Accuracy: 0.9811
# Epoch [23/100], Reconstruction Loss: 0.04827766916830364, Classification Loss: 0.10092153639241139
# Epoch 23, Validation Accuracy: 0.9759
# Epoch [24/100], Reconstruction Loss: 0.04828329218180829, Classification Loss: 0.10055969250410782
# Epoch 24, Validation Accuracy: 0.9833
# Epoch [25/100], Reconstruction Loss: 0.04827044632430426, Classification Loss: 0.1024955324469174
# Epoch 25, Validation Accuracy: 0.9795
# Epoch [26/100], Reconstruction Loss: 0.048291323369937265, Classification Loss: 0.09940636379176922
# Epoch 26, Validation Accuracy: 0.9791
# Epoch [27/100], Reconstruction Loss: 0.04825540488933231, Classification Loss: 0.09643107880966155
# Epoch 27, Validation Accuracy: 0.9764
# Epoch [28/100], Reconstruction Loss: 0.04827034893820826, Classification Loss: 0.09721402357803417
# Epoch 28, Validation Accuracy: 0.9790
# Epoch [29/100], Reconstruction Loss: 0.04828990256133026, Classification Loss: 0.09929030265534268
# Epoch 29, Validation Accuracy: 0.9776
# Epoch [30/100], Reconstruction Loss: 0.04829141226135328, Classification Loss: 0.09367946098409816
# Epoch 30, Validation Accuracy: 0.9790
# Epoch [31/100], Reconstruction Loss: 0.0482877698978906, Classification Loss: 0.09673260482242578
# Epoch 31, Validation Accuracy: 0.9879
# Epoch [32/100], Reconstruction Loss: 0.04831165624862321, Classification Loss: 0.0942028857119623
# Epoch 32, Validation Accuracy: 0.9832
# Epoch [33/100], Reconstruction Loss: 0.04825481866380905, Classification Loss: 0.09662420789702106
# Epoch 33, Validation Accuracy: 0.9842
# Epoch [34/100], Reconstruction Loss: 0.04828535765463624, Classification Loss: 0.0929705298443175
# Epoch 34, Validation Accuracy: 0.9884
# Epoch [35/100], Reconstruction Loss: 0.048307966064000514, Classification Loss: 0.0945031140019259
# Epoch 35, Validation Accuracy: 0.9801
# Epoch [36/100], Reconstruction Loss: 0.04828355729369806, Classification Loss: 0.09464203534388693
# Epoch 36, Validation Accuracy: 0.9858
# Epoch [37/100], Reconstruction Loss: 0.04828622512793382, Classification Loss: 0.08960736068857823
# Epoch 37, Validation Accuracy: 0.9908
# Epoch [38/100], Reconstruction Loss: 0.04830310384748737, Classification Loss: 0.08882363722798418
# Epoch 38, Validation Accuracy: 0.9784
# Epoch [39/100], Reconstruction Loss: 0.04826793449736297, Classification Loss: 0.08807870962689933
# Epoch 39, Validation Accuracy: 0.9794
# Epoch [40/100], Reconstruction Loss: 0.048383565670763934, Classification Loss: 0.09246537887981655
# Epoch 40, Validation Accuracy: 0.9843
# Epoch [41/100], Reconstruction Loss: 0.04825582559910828, Classification Loss: 0.08736988145367003
# Epoch 41, Validation Accuracy: 0.9855
# Epoch [42/100], Reconstruction Loss: 0.04860258940620848, Classification Loss: 0.08930149245501535
# Epoch 42, Validation Accuracy: 0.9917
# Epoch [43/100], Reconstruction Loss: 0.04827451965928528, Classification Loss: 0.08613728009635342
# Epoch 43, Validation Accuracy: 0.9849
# Epoch [44/100], Reconstruction Loss: 0.04829996197804893, Classification Loss: 0.086028523816532
# Epoch 44, Validation Accuracy: 0.9942
# Epoch [45/100], Reconstruction Loss: 0.04829741813169868, Classification Loss: 0.09021719802018141
# Epoch 45, Validation Accuracy: 0.9861
# Epoch [46/100], Reconstruction Loss: 0.0482784291594757, Classification Loss: 0.08757684097582939
# Epoch 46, Validation Accuracy: 0.9861
# Epoch [47/100], Reconstruction Loss: 0.048273081284572535, Classification Loss: 0.08241984533017542
# Epoch 47, Validation Accuracy: 0.9913
# Epoch [48/100], Reconstruction Loss: 0.04827535949102632, Classification Loss: 0.08892777062755396
# Epoch 48, Validation Accuracy: 0.9690
# Epoch [49/100], Reconstruction Loss: 0.048279267316217046, Classification Loss: 0.08090500968732757
# Epoch 49, Validation Accuracy: 0.9898
# Epoch [50/100], Reconstruction Loss: 0.04827936436438876, Classification Loss: 0.08489258163330392
# Epoch 50, Validation Accuracy: 0.9930
# Epoch [51/100], Reconstruction Loss: 0.048404346293168525, Classification Loss: 0.08457806735194738
# Epoch 51, Validation Accuracy: 0.9855
# Epoch [52/100], Reconstruction Loss: 0.0482737553655356, Classification Loss: 0.09023950680250148
# Epoch 52, Validation Accuracy: 0.9916
# Epoch [53/100], Reconstruction Loss: 0.04827881898221399, Classification Loss: 0.08095022210957116
# Epoch 53, Validation Accuracy: 0.9922
# Epoch [54/100], Reconstruction Loss: 0.048511918806387666, Classification Loss: 0.08847572464322061
# Epoch 54, Validation Accuracy: 0.9919
# Epoch [55/100], Reconstruction Loss: 0.04822931197046939, Classification Loss: 0.07592684891512058
# Epoch 55, Validation Accuracy: 0.9836
# Epoch [56/100], Reconstruction Loss: 0.04854679788117718, Classification Loss: 0.08427126028481316
# Epoch 56, Validation Accuracy: 0.9817
# Epoch [57/100], Reconstruction Loss: 0.04825976857383994, Classification Loss: 0.07771856162406267
# Epoch 57, Validation Accuracy: 0.9802
# Epoch [58/100], Reconstruction Loss: 0.048323584621660344, Classification Loss: 0.0850039496606286
# Epoch 58, Validation Accuracy: 0.9932
# Epoch [59/100], Reconstruction Loss: 0.04828371851932328, Classification Loss: 0.08221113616723158
# Epoch 59, Validation Accuracy: 0.9924
# Epoch [60/100], Reconstruction Loss: 0.048432737674446606, Classification Loss: 0.08696920812634086
# Epoch 60, Validation Accuracy: 0.9853
# Epoch [61/100], Reconstruction Loss: 0.048259690571817344, Classification Loss: 0.07459334089835154
# Epoch 61, Validation Accuracy: 0.9915
# Epoch [62/100], Reconstruction Loss: 0.048505175904225845, Classification Loss: 0.08144842912121102
# Epoch 62, Validation Accuracy: 0.9716
# Epoch [63/100], Reconstruction Loss: 0.048727941188242634, Classification Loss: 0.10070518308905475
# Epoch 63, Validation Accuracy: 0.9891
# Epoch [64/100], Reconstruction Loss: 0.0482890575941149, Classification Loss: 0.08100888504308794
# Epoch 64, Validation Accuracy: 0.9908
# Epoch [65/100], Reconstruction Loss: 0.04827065560124627, Classification Loss: 0.0784252180824773
# Epoch 65, Validation Accuracy: 0.9817
# Epoch [66/100], Reconstruction Loss: 0.04838169247143784, Classification Loss: 0.08326664960695473
# Epoch 66, Validation Accuracy: 0.9923
# Epoch [67/100], Reconstruction Loss: 0.04827366215908643, Classification Loss: 0.09000246492097391
# Epoch 67, Validation Accuracy: 0.9943
# Epoch [68/100], Reconstruction Loss: 0.048380138032189254, Classification Loss: 0.07458274580351033
# Epoch 68, Validation Accuracy: 0.9943
# Epoch [69/100], Reconstruction Loss: 0.04826352524452387, Classification Loss: 0.07204822877921957
# Epoch 69, Validation Accuracy: 0.9940
# Epoch [70/100], Reconstruction Loss: 0.04828778132720471, Classification Loss: 0.07169271152041964
# Epoch 70, Validation Accuracy: 0.9875
# Epoch [71/100], Reconstruction Loss: 0.048347408233283824, Classification Loss: 0.07941026129306439
# Epoch 71, Validation Accuracy: 0.9744
# Epoch [72/100], Reconstruction Loss: 0.04831182222739176, Classification Loss: 0.07548111661324522
# Epoch 72, Validation Accuracy: 0.9783
# Epoch [73/100], Reconstruction Loss: 0.048305539950145714, Classification Loss: 0.07604731400286902
# Epoch 73, Validation Accuracy: 0.9874
# Epoch [74/100], Reconstruction Loss: 0.048340070953716945, Classification Loss: 0.07604347921180944
# Epoch 74, Validation Accuracy: 0.9947
# Epoch [75/100], Reconstruction Loss: 0.04840572493813953, Classification Loss: 0.07557153214882209
# Epoch 75, Validation Accuracy: 0.9770
# Epoch [76/100], Reconstruction Loss: 0.048257412723325024, Classification Loss: 0.07784066936517173
# Epoch 76, Validation Accuracy: 0.9734
# Epoch [77/100], Reconstruction Loss: 0.048289104839070694, Classification Loss: 0.07804736203837545
# Epoch 77, Validation Accuracy: 0.9903
# Epoch [78/100], Reconstruction Loss: 0.04826865508353091, Classification Loss: 0.07109802284131826
# Epoch 78, Validation Accuracy: 0.9815
# Epoch [79/100], Reconstruction Loss: 0.04828434672110787, Classification Loss: 0.07547149765862675
# Epoch 79, Validation Accuracy: 0.9850
# Epoch [80/100], Reconstruction Loss: 0.048264431920829146, Classification Loss: 0.07630982527373337
# Epoch 80, Validation Accuracy: 0.9882
# Epoch [81/100], Reconstruction Loss: 0.048280919194362296, Classification Loss: 0.07210222943863305
# Epoch 81, Validation Accuracy: 0.9919
# Epoch [82/100], Reconstruction Loss: 0.048328111886432275, Classification Loss: 0.0717780794113175
# Epoch 82, Validation Accuracy: 0.9947
# Epoch [83/100], Reconstruction Loss: 0.04827298748783896, Classification Loss: 0.06866483453496608
# Epoch 83, Validation Accuracy: 0.9908
# Epoch [84/100], Reconstruction Loss: 0.048448044348029934, Classification Loss: 0.0734149951374969
# Epoch 84, Validation Accuracy: 0.9763
# Epoch [85/100], Reconstruction Loss: 0.04834617152409353, Classification Loss: 0.06971664950840849
# Epoch 85, Validation Accuracy: 0.9956
# Epoch [86/100], Reconstruction Loss: 0.04833899886564107, Classification Loss: 0.0840317512327896
# Epoch 86, Validation Accuracy: 0.9797
# Epoch [87/100], Reconstruction Loss: 0.04834528499923139, Classification Loss: 0.08351491861434122
# Epoch 87, Validation Accuracy: 0.9976
# Epoch [88/100], Reconstruction Loss: 0.048258375346136397, Classification Loss: 0.07642015543483904
# Epoch 88, Validation Accuracy: 0.9957
# Epoch [89/100], Reconstruction Loss: 0.04829701306825028, Classification Loss: 0.06973405242523058
# Epoch 89, Validation Accuracy: 0.9937
# Epoch [90/100], Reconstruction Loss: 0.04827708913805891, Classification Loss: 0.08513161934873822
# Epoch 90, Validation Accuracy: 0.9912
# Epoch [91/100], Reconstruction Loss: 0.0482922683275401, Classification Loss: 0.07292672242253893
# Epoch 91, Validation Accuracy: 0.9770
# Epoch [92/100], Reconstruction Loss: 0.048376332219516247, Classification Loss: 0.0709944218861854
# Epoch 92, Validation Accuracy: 0.9872
# Epoch [93/100], Reconstruction Loss: 0.04829034495403954, Classification Loss: 0.08025717880419597
# Epoch 93, Validation Accuracy: 0.9812
# Epoch [94/100], Reconstruction Loss: 0.048268440865529345, Classification Loss: 0.06987239900214669
# Epoch 94, Validation Accuracy: 0.9980
# Epoch [95/100], Reconstruction Loss: 0.0482711494618818, Classification Loss: 0.07150529533355264
# Epoch 95, Validation Accuracy: 0.9742
# Epoch [96/100], Reconstruction Loss: 0.04830835444514515, Classification Loss: 0.07144839464657399
# Epoch 96, Validation Accuracy: 0.9946
# Epoch [97/100], Reconstruction Loss: 0.04848483265982081, Classification Loss: 0.0722853913953562
# Epoch 97, Validation Accuracy: 0.9924
# Epoch [98/100], Reconstruction Loss: 0.04834335052188546, Classification Loss: 0.0789378008152044
# Epoch 98, Validation Accuracy: 0.9956
# Epoch [99/100], Reconstruction Loss: 0.04827057435049326, Classification Loss: 0.06552736565010653
# Epoch 99, Validation Accuracy: 0.9881
# Epoch [100/100], Reconstruction Loss: 0.04828252315495246, Classification Loss: 0.07147939378554552
# Epoch 100, Validation Accuracy: 0.9748

# %% [markdown]
# Step 4: Evaluating the Model and Calculating Metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


model.eval()
true_labels = []
predicted_labels = []

test_data = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False)

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.view(-1, num_input_features)
        inputs, labels = inputs.to(device), labels.to(device)
        decoded, classification = model(inputs)
        _, predicted = torch.max(classification, 1)
        true_labels.extend(labels.cpu().tolist())
        predicted_labels.extend(predicted.cpu().tolist())

accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted', zero_division=1)
recall = recall_score(true_labels, predicted_labels, average='weighted', zero_division=1)
f1 = f1_score(true_labels, predicted_labels, average='weighted', zero_division=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.9752966110357705
# Precision: 0.9763750915720529
# Recall: 0.9752966110357705
# F1 Score: 0.9753102209243277
# Confusion Matrix:
#  [[73453  3462     0     0     0]
#  [  155 66016     0     0     0]
#  [    0     0    18     1     0]
#  [    0     0     2  3629     0]
#  [    1     4     0     0     0]]
